# %% [markdown]
# ## SeqNeo
# - Stage: Cambrian
# - Version: Pomoria
#
# #### Related Commands
# - tensorboard --logdir runs
# - nohup jupyter lab > jupyter.log &

# %%
import logging 
logging.basicConfig(level=logging.CRITICAL)

# %%
import os
import itertools
import copy
import random
import pickle
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.autograd import Variable

# from tensorboardX import SummaryWriter

use_cuda = torch.cuda.is_available()
print("use_cuda: {}".format(use_cuda))
# Out:
# use_cuda: True

# %%
from tyrell import spec as S
from tyrell import dsl as D
from tyrell.decider import Example

# Morpheus Version
from MorpheusInterpreter import *
from ProgramSpace import *

# %%
torch.__version__
# Out:
# '1.0.0'

# %%
class SeqNeo(nn.Module):
    def __init__(self, p_config=None):
        super(SeqNeo, self).__init__()
        self.config = p_config
        
        self.fn_embedding = nn.Embedding(
            self.config["fn_vocab_size"],
            self.config["fn_dim"],
            padding_idx=0,
        )
        
        self.encoder1 = nn.Linear(
            self.config["encoder"]["input_dim"],
            2048,
        )
        self.encoder2 = nn.Linear(
            2048,
            self.config["encoder"]["output_dim"],
        )
        
        self.decoder = nn.GRUCell(
            self.config["decoder"]["input_dim"],
            self.config["decoder"]["hidden_dim"],
            bias=True,
        )
        self.classifier = nn.Linear(
            self.config["decoder"]["hidden_dim"],
            self.config["decoder"]["output_dim"],
        )
        
    def decode(self, pin_exp, pout_exp, p_hidden, pfn_context):
        tmp_exp = self.encode(pin_exp, pout_exp) # (B=1, encoder_output_dim)
        tmp_fn = self.fn_embedding(pfn_context) # (B=1, fn_dim)
        tmp_input = torch.cat([tmp_exp,tmp_fn],dim=1)
        
        if p_hidden is None:
            # very first
            tmp_hidden = self.decoder(tmp_input)
        else:
            # not the very first
            tmp_hidden = self.decoder(tmp_input, p_hidden)
        # (B=1, decoder_hidden_dim)
        
        tmp_output = torch.log_softmax(
            self.classifier(tmp_hidden),
            dim=1
        ) # (B=1, decoder_output_dim)
        
        # first hidden, then output
        return (tmp_hidden, tmp_output)
        
        
    def encode(self, pin_exp, pout_exp):
        # pin_exp/pout_exp: (B=1, abs_dim)
        tmp_exp = torch.cat([pin_exp,pout_exp],dim=1) # (B=1, encoder_input_dim=abs_dim*2)
        tmp_out1 = F.relu(self.encoder1(tmp_exp))
        tmp_out2 = F.relu(self.encoder2(tmp_out1))
        return tmp_out2 # (B=1, encoder_output_dim)

# %%
# replace certain node id with certain value
def modify_shell(p_shell, p_id_from, p_id_to):
    d_prod = p_shell[0]
    d_rhs = p_shell[1]
    ld_rhs = [p_id_to if d_rhs[i]==p_id_from else d_rhs[i]
             for i in range(len(d_rhs))]
    return (d_prod, tuple(ld_rhs))

# using default path and solutions
from benchmarks.pldi17_sol import *
def load_benchmark(p_id, p_sourceps, p_builder):
    d_prog = p_builder._from_sexp(solutions[p_id])
    d_input = p_sourceps.interpreter.init_tbl("./benchmarks/pldi17/p{}_input1.csv".format(p_id))
    p_sourceps.interpreter.create_shadow(d_input)
    d_output = p_sourceps.interpreter.init_tbl("./benchmarks/pldi17/p{}_output1.csv".format(p_id))
    p_sourceps.interpreter.create_shadow(d_output)
    d_ps = ProgramSpace(
        p_sourceps.spec, p_sourceps.interpreter, [d_input], d_output,
    )
    d_ps.init_by_prog(d_prog)
    return d_ps

# %%
def SeqBeam(p_config, p_sourceps, p_model, p_dataset):
    print("# Start Beam Search...")
    p_builder = D.Builder(p_sourceps.spec)
    
    for d_episode in range(p_config["train"]["n_episode"]):
        p_model.eval()

        if isinstance(p_dataset,list):
            print("# sample from dataset #")
            # ====== option 1: sample from dataset ====== #
            eid = random.choice(range(len(p_dataset)))
            data_prog, data_str_example = p_dataset[eid]
            data_example = Example(
                input=[p_sourceps.interpreter.load_data_into_var(p) for p in data_str_example.input],
                output=p_sourceps.interpreter.load_data_into_var(data_str_example.output),
            )
            ps_solution = ProgramSpace(
                p_sourceps.spec, p_sourceps.interpreter, data_example.input, data_example.output,
            )
            ps_solution.init_by_prog(data_prog)
        elif isinstance(p_dataset, tuple):
            print("# designated data #")
            data_prog, data_str_example = p_dataset
            data_example = Example(
                input=[p_sourceps.interpreter.load_data_into_var(p) for p in data_str_example.input],
                output=p_sourceps.interpreter.load_data_into_var(data_str_example.output),
            )
            ps_solution = ProgramSpace(
                p_sourceps.spec, p_sourceps.interpreter, data_example.input, data_example.output,
            )
            ps_solution.init_by_prog(data_prog)
        elif isinstance(p_dataset,int):
            print("# load Morpheus benchmark: {} #".format(p_dataset))
            # ====== option 2: load Morpheus benchmarks ====== #
            ps_solution = load_benchmark(p_dataset, p_sourceps, p_builder)
        else:
            print("# sample from generator #")
            # ====== option 3: sample from generator ====== #
            ps_solution = p_dataset.get_new_chain_program(
                p_config["train"]["n_size"] + 1 # depth=size+1
            )

        # solution self-check
        if ps_solution.check_eq() is None:
            print("ERROR, SOLUTION NOT CONSISTENT!")
            continue
        else:
            print("==== Problem ====")
            print(str(ps_solution.node_list[-1]))

        selected_neurons = []

        # initialize a new Program Space
        ps_current = ProgramSpace(
            p_sourceps.spec, p_sourceps.interpreter, ps_solution.inputs, ps_solution.output,
        )
        # then initialize a shell template
        tmp_shell_list = ps_current.get_neighboring_shells()
        tmp_node_to_replace = ps_current.node_dict["ParamNode"][0] # for chain only
        # replace the Param Node id in shells with -1 to make them templates
        template_list = [
            modify_shell(tmp_shell_list[i],tmp_node_to_replace,-1)
            for i in range(len(tmp_shell_list))
        ]
        
        beam_list = [
            # (score, hidden, fn_context, ProgramSpace)
            (0.0, None, 0, ps_current.make_copy())
        ]
        dead_list = []

        for d_step in range(len(ps_solution.shells)):
            sprout_list = []
            for d_bid in range(len(beam_list)):
                dd_score, dd_hidden, dd_context, dd_ps = beam_list[d_bid]
                ps_current = dd_ps
                
                # ### assume chain execution, so only 1 possible returns
                # ### at d_step=0, this should be input[0]
                id_current = ps_current.get_strict_frontiers()[0]
                var_current = ps_current.node_list[id_current].ps_data # need the real var name in r env
                var_output = ps_current.output

                map_current = p_sourceps.interpreter.camb_get_pomoria(var_current)
                map_output = p_sourceps.interpreter.camb_get_pomoria(var_output)

                # make current shell list
                current_shell_list = [
                    modify_shell(template_list[i],-1,id_current)
                    for i in range(len(template_list))
                ]
                current_shell_list = [None] + current_shell_list # None for <SOS> in nn embedding

                # wrap in B=1
                if use_cuda:
                    td_current = Variable(torch.tensor([map_current],dtype=torch.float)).cuda()
                    td_output = Variable(torch.tensor([map_output],dtype=torch.float)).cuda()
                    td_context = Variable(torch.tensor([dd_context],dtype=torch.long)).cuda()
                else:
                    td_current = Variable(torch.tensor([map_current],dtype=torch.float))
                    td_output = Variable(torch.tensor([map_output],dtype=torch.float))
                    td_context = Variable(torch.tensor([dd_context],dtype=torch.long))

                # (B=1, fn_vocab_size)
                hidden_current, td_pred = p_model.decode(td_current, td_output, dd_hidden, td_context)
                
                # start sprouting
                np_pred = td_pred.data.cpu().numpy().flatten()
                as_pred = np.argsort(np_pred)[::-1]
                for i in range(p_config["test"]["sprout_size"]):
                    ppps = ps_current.make_copy()
                    tmp_id = as_pred[i]
                    fn_context = tmp_id
                    # try to update
                    update_status = ppps.add_neighboring_shell(
                        current_shell_list[tmp_id]
                    )
                    if update_status:
                        # success, put into sprout list
                        sprout_list.append(
                            (
                                dd_score+np_pred[tmp_id],
                                hidden_current,
                                fn_context,
                                ppps,
                            )
                        )
                    else:
                        # recorded in dead_list
                        dead_list.append((
                            ppps.get_node_from_shell(current_shell_list[tmp_id]),
                            ppps,
                        ))
                # <END_FOR_SPROUT>
            # <END_FOR_BEAM>
            sorted_sprout_list = sorted(
                sprout_list,
                key=lambda x:x[0],
                reverse=True,
            )
            if len(sorted_sprout_list)>p_config["test"]["beam_size"]:
                beam_list = sorted_sprout_list[:p_config["test"]["beam_size"]]
            else:
                beam_list = sorted_sprout_list
        # <END_FOR_STEP>
        
        # then print and seek for correct solutions
        print("==== beam search ====")
        for i in range(len(beam_list)):
            dd_score, dd_hidden, dd_context, dd_ps = beam_list[i]
            print("#{}{}, {:.4f}, {}".format(
                "(solved)" if dd_ps.check_eq() is not None else "",
                i+1,
                dd_score,
                str(dd_ps.node_list[-1])
            ))
        print("==== dead list ({}) ====".format(len(dead_list)))
#         for i in range(len(dead_list)):
#             print("{}---{}".format(
#                 str(dead_list[i][0]),
#                 str(dead_list[i][1].node_list[-1]),
#             ))

        if isinstance(p_dataset,int):
            return
        else:
            input("==== Press to enter next problem ====")

    # <END_FOR_EPISODE>

# %%
m_interpreter = MorpheusInterpreter()
m_spec = S.parse_file('./example/camb6.tyrell')
m_generator = MorpheusGenerator(
    spec=m_spec,
    interpreter=m_interpreter,
)
# dumb variable to help infer the shells
m_ps = ProgramSpace(
    m_spec, m_interpreter, [None], None,
)

# %%
m_config = {
    "abs_dim": 15*9+3,
    "fn_dim": 128,
    "fn_vocab_size": len(m_ps.get_neighboring_shells())+1, # with one more <SOS>
    "encoder":{
        "input_dim": None,
        "output_dim": 1024, # hidden state
    },
    "decoder":{
        "input_dim": None,
        "hidden_dim": None,
        "output_dim": None,
    },
    "train":{
        "n_epoch":500, # #epoches in total
        "n_episode": 100, # #problems per epoch
        "n_size": 3,
    },
    "test":{
        "beam_size": 10,
        "sprout_size": 10,
    },
}
m_config["encoder"]["input_dim"] = m_config["abs_dim"]*2
m_config["decoder"]["input_dim"] = \
    m_config["encoder"]["output_dim"] + \
    m_config["fn_dim"]
m_config["decoder"]["hidden_dim"] = m_config["encoder"]["output_dim"]
m_config["decoder"]["output_dim"] = m_config["fn_vocab_size"]

# %%
# with open("./0812Size3RelaxedFiltered.pkl","rb") as f:
#     m_dataset = pickle.load(f)

# %%
seq_neo = SeqNeo(p_config=m_config)
seq_neo.load_state_dict(torch.load("./saved_models/0813CambAgent_Thomas_Size3_ep40.pt"))
if use_cuda:
    seq_neo = seq_neo.cuda()

# %%
SeqBeam(m_config, m_ps, seq_neo, m_dataset[-11])

# %%
bmrk_size3 = [1,2,3,9,10,13,21,22,23,31,42,44,47,51,52,53,56,59,60,61,63,64,90,]

# %%
for did in bmrk_size3:
    SeqBeam(m_config, m_ps, seq_neo, did)
    print()
    print()
# Out:
# # Start Beam Search...
# # load Morpheus benchmark: 1 #
# ==== Problem ====
# spread(unite(neg_gather(@param0, ['1', '4']), 3, 1), 1, 3)
# ==== beam search ====
# #1, -7.0295, spread(unite(gather(@param0, ['2', '3']), 2, 4), 1, 2)
# #2, -7.6055, spread(unite(gather(@param0, ['2', '3']), 4, 1), 1, 4)
# #3, -7.8658, spread(unite(gather(@param0, ['1', '4']), 5, 4), 4, 1)
# #4, -7.9474, spread(unite(gather(@param0, ['3', '5']), 3, 1), 1, 3)
# #5, -8.1732, spread(unite(gather(@param0, ['3', '5']), 3, 1), 1, 4)
# #6, -8.8714, spread(unite(gather(@param0, ['2', '3']), 4, 1), 2, 1)
# #7, -8.8761, spread(unite(gather(@param0, ['1', '4']), 4, 5), 4, 1)
# #8, -9.0748, spread(unite(gather(@param0, ['1', '4']), 5, 4), 4, 2)
# #9, -9.0883, spread(unite(gather(@param0, ['2', '3']), 2, 4), 1, 4)
# #10, -9.1021, spread(unite(gather(@param0, ['2', '3']), 4, 1), 1, 3)
# ==== dead list (66) ====
#
#
# # Start Beam Search...
# # load Morpheus benchmark: 2 #
# ==== Problem ====
# spread(unite(gather(@param0, ['3', '4']), 2, 3), 2, 3)
# ==== beam search ====
# #1, -4.8911, summarise(group_by(neg_gather(@param0, ['3', '4']), ['3']), mean, 2)
# #2, -5.3157, summarise(group_by(neg_gather(@param0, ['3', '4']), ['1', '3']), max, 2)
# #3, -5.3978, summarise(group_by(neg_gather(@param0, ['3', '4']), ['3', '4']), mean, 2)
# #4, -5.5935, summarise(group_by(neg_gather(@param0, ['3', '4']), ['3']), max, 2)
# #5, -5.6491, summarise(group_by(neg_gather(@param0, ['3', '4']), ['1', '3']), mean, 2)
# #6, -5.6790, summarise(group_by(neg_gather(@param0, ['3', '4']), ['3', '4']), min, 2)
# #7, -5.7425, summarise(group_by(neg_gather(@param0, ['3', '4']), ['3', '4']), max, 2)
# #8, -5.7845, summarise(group_by(neg_gather(@param0, ['3', '4']), ['1', '3']), min, 2)
# #9, -5.7985, summarise(group_by(neg_gather(@param0, ['3', '4']), ['3']), min, 2)
# #10, -5.8236, summarise(group_by(neg_gather(@param0, ['3', '4']), ['1', '2']), mean, 2)
# ==== dead list (47) ====
#
#
# # Start Beam Search...
# # load Morpheus benchmark: 3 #
# ==== Problem ====
# spread(unite(gather(@param0, ['3', '4']), 2, 3), 2, 3)
# ==== beam search ====
# #1, -4.7118, summarise(group_by(neg_gather(@param0, ['3', '4']), ['3', '4']), mean, 2)
# #2, -5.2134, summarise(group_by(neg_gather(@param0, ['3', '4']), ['3', '4']), sum, 2)
# #3, -5.2654, summarise(group_by(neg_gather(@param0, ['3', '4']), ['1', '3']), max, 2)
# #4, -5.2740, summarise(group_by(neg_gather(@param0, ['3', '4']), ['3', '4']), max, 2)
# #5, -5.3446, summarise(group_by(neg_gather(@param0, ['3', '4']), ['1', '3']), mean, 2)
# #6, -5.4896, summarise(group_by(neg_gather(@param0, ['3', '4']), ['3', '4']), min, 2)
# #7, -5.6657, summarise(group_by(neg_gather(@param0, ['3', '4']), ['3']), mean, 2)
# #8, -5.7123, summarise(group_by(neg_gather(@param0, ['3', '4']), ['1', '2']), mean, 2)
# #9, -5.9317, summarise(group_by(neg_gather(@param0, ['3', '4']), ['2', '4']), max, 2)
# #10, -6.0415, summarise(group_by(neg_gather(@param0, ['3', '4']), ['1', '3']), sum, 2)
# ==== dead list (50) ====
#
#
# # Start Beam Search...
# # load Morpheus benchmark: 9 #
# ==== Problem ====
# neg_select(mutate(spread(@param0, 3, 4), /, 3, 4), ['3', '4'])
# ==== beam search ====
# #1, -3.8140, summarise(group_by(neg_gather(@param0, ['2', '4']), ['1', '3']), mean, 2)
# #2, -3.9165, summarise(group_by(neg_gather(@param0, ['2', '4']), ['1', '3']), min, 1)
# #3, -4.3823, summarise(group_by(neg_gather(@param0, ['2', '4']), ['1', '3']), sum, 1)
# #4, -4.5814, summarise(group_by(gather(@param0, ['1', '3']), ['1', '3']), mean, 2)
# #5, -4.7067, summarise(group_by(gather(@param0, ['1', '3']), ['1', '3']), min, 1)
# #6, -5.1814, summarise(group_by(neg_gather(@param0, ['2', '4']), ['1', '2']), mean, 2)
# #7, -5.2024, summarise(group_by(neg_gather(@param0, ['2', '4']), ['1', '2']), min, 1)
# #8, -5.3625, summarise(group_by(gather(@param0, ['1', '3']), ['1', '3']), sum, 1)
# #9, -5.5803, summarise(group_by(neg_gather(@param0, ['2', '4']), ['1', '3']), mean, 1)
# #10, -5.9257, summarise(group_by(neg_gather(@param0, ['2', '4']), ['1', '2']), sum, 1)
# ==== dead list (29) ====
#
#
# # Start Beam Search...
# # load Morpheus benchmark: 10 #
# ==== Problem ====
# neg_select(gather(separate(@param0, 4), ['4', '5']), ['4'])
# ==== beam search ====
# #1, -3.3268, neg_select(gather(separate(@param0, 1), ['1', '2']), ['2'])
# #2, -3.4389, neg_select(gather(separate(@param0, 4), ['3', '4']), ['2', '4'])
# #3, -3.8245, neg_select(gather(separate(@param0, 3), ['3', '4']), ['2', '4'])
# #4, -4.4750, neg_select(gather(separate(@param0, 1), ['1', '2']), ['1', '4'])
# #5, -4.5313, neg_select(gather(separate(@param0, 1), ['1', '2']), ['4'])
# #6, -4.5617, neg_select(gather(separate(@param0, 1), ['1', '2']), ['3', '4'])
# #7, -4.8764, neg_select(gather(separate(@param0, 1), ['1', '2']), ['2', '4'])
# #8, -4.8793, neg_select(gather(separate(@param0, 4), ['3', '4']), ['3', '4'])
# #9, -5.0781, neg_select(gather(separate(@param0, 1), ['1', '4']), ['3', '5'])
# #10, -5.0927, neg_select(gather(separate(@param0, 1), ['2', '4']), ['2'])
# ==== dead list (78) ====
#
#
# # Start Beam Search...
# # load Morpheus benchmark: 13 #
# ==== Problem ====
# spread(unite(gather(@param0, ['3', '4']), 2, 3), 2, 3)
# ==== beam search ====
# #1, -4.2739, summarise(group_by(neg_gather(@param0, ['2', '3']), ['3', '4']), sum, 4)
# #2, -4.2990, summarise(group_by(neg_gather(@param0, ['2', '3']), ['1', '2']), sum, 4)
# #3, -4.3684, summarise(group_by(neg_gather(@param0, ['2', '3']), ['3']), min, 4)
# #4, -4.4809, summarise(group_by(neg_gather(@param0, ['2', '3']), ['2', '4']), sum, 4)
# #5, -4.5743, summarise(group_by(neg_gather(@param0, ['2', '3']), ['2', '3']), min, 4)
# #6, -4.7445, summarise(group_by(neg_gather(@param0, ['2', '3']), ['3']), mean, 2)
# #7, -4.7827, summarise(group_by(neg_gather(@param0, ['2', '3']), ['1', '2']), mean, 2)
# #8, -4.8673, summarise(group_by(neg_gather(@param0, ['2', '3']), ['1', '4']), min, 4)
# #9, -4.9308, summarise(group_by(neg_gather(@param0, ['2', '3']), ['1', '2']), min, 4)
# #10, -4.9376, summarise(group_by(neg_gather(@param0, ['2', '3']), ['1']), sum, 4)
# ==== dead list (41) ====
#
#
# # Start Beam Search...
# # load Morpheus benchmark: 21 #
# ==== Problem ====
# spread(separate(neg_gather(@param0, ['1']), 2), 3, 4)
# ==== beam search ====
# #1, -5.4260, summarise(group_by(gather(@param0, ['1', '3']), ['1', '3']), max, 3)
# #2, -5.6475, summarise(group_by(gather(@param0, ['1', '4']), ['1', '3']), min, 2)
# #3, -5.8101, summarise(group_by(gather(@param0, ['3', '4']), ['4', '5']), max, 3)
# #4, -6.0332, summarise(group_by(gather(@param0, ['1', '4']), ['1', '3']), min, 1)
# #5, -6.0516, summarise(group_by(gather(@param0, ['3', '5']), ['1', '3']), min, 2)
# #6, -6.2222, summarise(group_by(gather(@param0, ['3', '4']), ['1', '3']), max, 3)
# #7, -6.3031, summarise(group_by(gather(@param0, ['4', '5']), ['3', '4']), min, 2)
# #8, -6.3562, summarise(group_by(gather(@param0, ['1', '2']), ['3', '5']), max, 2)
# #9, -6.3831, summarise(group_by(gather(@param0, ['1', '4']), ['1', '3']), mean, 3)
# #10, -6.3903, summarise(group_by(gather(@param0, ['1', '3']), ['1', '3']), min, 2)
# ==== dead list (38) ====
#
#
# # Start Beam Search...
# # load Morpheus benchmark: 22 #
# ==== Problem ====
# summarise(group_by(gather(@param0, ['4', '5']), ['4']), mean, 5)
# ==== beam search ====
# #1, -4.0453, summarise(group_by(gather(@param0, ['1', '2']), ['3']), max, 3)
# #2, -5.1670, summarise(group_by(gather(@param0, ['3', '5']), ['3']), max, 3)
# #3, -5.2992, summarise(group_by(gather(@param0, ['1', '2']), ['3']), mean, 2)
# #4, -5.3752, summarise(group_by(gather(@param0, ['3', '4']), ['3']), max, 3)
# #5, -5.4938, summarise(group_by(gather(@param0, ['1', '2']), ['2']), max, 3)
# #6, -5.6578, summarise(group_by(gather(@param0, ['1', '2']), ['3']), mean, 3)
# #7, -5.7797, summarise(group_by(gather(@param0, ['1', '2']), ['3']), min, 3)
# #8, -5.8136, summarise(group_by(gather(@param0, ['3', '5']), ['3']), mean, 3)
# #9, -6.0310, summarise(group_by(gather(@param0, ['3', '5']), ['1', '3']), mean, 3)
# #10, -6.0493, summarise(group_by(gather(@param0, ['1', '2']), ['3']), sum, 3)
# ==== dead list (35) ====
#
#
# # Start Beam Search...
# # load Morpheus benchmark: 23 #
# ==== Problem ====
# summarise(group_by(neg_gather(@param0, ['1']), ['1']), sum, 3)
# ==== beam search ====
# #1, -2.4721, summarise(group_by(neg_gather(@param0, ['2', '3']), ['3']), mean, 2)
# #2, -2.8442, summarise(group_by(neg_gather(@param0, ['2', '3']), ['3']), sum, 1)
# #3, -3.0987, summarise(group_by(neg_gather(@param0, ['2', '3']), ['1']), sum, 1)
# #4, -3.1285, summarise(group_by(neg_gather(@param0, ['2', '3']), ['3']), min, 1)
# #5, -3.4319, summarise(group_by(neg_gather(@param0, ['2', '3']), ['1']), mean, 2)
# #6, -3.6389, summarise(group_by(neg_gather(@param0, ['2', '3']), ['1']), min, 1)
# #7, -3.7227, summarise(group_by(neg_gather(@param0, ['2', '3']), ['3']), min, 4)
# #8, -4.1759, summarise(group_by(neg_gather(@param0, ['2', '3']), ['1']), max, 1)
# #9, -4.2093, summarise(group_by(neg_gather(@param0, ['2', '3']), ['1']), min, 4)
# #10, -4.3957, summarise(group_by(neg_gather(@param0, ['1', '3']), ['3']), mean, 2)
# ==== dead list (25) ====
#
#
# # Start Beam Search...
# # load Morpheus benchmark: 31 #
# ==== Problem ====
# spread(separate(neg_gather(@param0, ['1']), 2), 3, 4)
# ==== beam search ====
# #1, -3.8267, summarise(group_by(gather(@param0, ['3', '6']), ['4', '6']), max, 5)
# #2, -4.6844, summarise(group_by(gather(@param0, ['3', '5']), ['1', '6']), mean, 2)
# #3, -5.4713, summarise(group_by(gather(@param0, ['3', '4']), ['4', '6']), max, 5)
# #4, -5.6836, summarise(group_by(gather(@param0, ['3', '5']), ['1', '3']), min, 2)
# #5, -5.7289, summarise(group_by(gather(@param0, ['5', '6']), ['4', '6']), max, 5)
# #6, -5.9088, summarise(group_by(gather(@param0, ['3', '4']), ['3', '5']), max, 2)
# #7, -6.0710, summarise(group_by(gather(@param0, ['3', '4']), ['2', '6']), min, 2)
# #8, -6.3389, summarise(group_by(gather(@param0, ['3', '5']), ['1', '3']), mean, 2)
# #9, -6.3728, summarise(group_by(gather(@param0, ['3', '5']), ['2', '5']), mean, 5)
# #10, -6.3908, summarise(group_by(gather(@param0, ['3', '6']), ['4', '6']), mean, 2)
# ==== dead list (16) ====
#
#
# # Start Beam Search...
# # load Morpheus benchmark: 42 #
# ==== Problem ====
# spread(separate(neg_gather(@param0, ['5']), 2), 3, 4)
# ==== beam search ====
# #1, -6.4811, summarise(group_by(neg_gather(@param0, ['2', '5']), ['1', '3']), min, 1)
# #2, -6.5859, summarise(group_by(neg_gather(@param0, ['2', '5']), ['2', '4']), min, 1)
# #3, -6.7011, summarise(group_by(neg_gather(@param0, ['2', '5']), ['2', '4']), mean, 2)
# #4, -6.7157, summarise(group_by(neg_gather(@param0, ['5', '6']), ['1', '3']), min, 1)
# #5, -6.8360, summarise(group_by(neg_gather(@param0, ['2', '5']), ['1', '3']), mean, 2)
# #6, -6.9629, summarise(group_by(neg_gather(@param0, ['5', '6']), ['1', '2']), min, 1)
# #7, -7.7188, summarise(group_by(neg_gather(@param0, ['5', '6']), ['3']), min, 1)
# #8, -7.7495, summarise(group_by(neg_gather(@param0, ['2', '5']), ['2', '4']), sum, 1)
# #9, -7.8708, summarise(group_by(neg_gather(@param0, ['2', '5']), ['1', '3']), sum, 1)
# #10, -7.8898, summarise(group_by(neg_gather(@param0, ['5', '6']), ['1', '3']), sum, 1)
# ==== dead list (54) ====
#
#
# # Start Beam Search...
# # load Morpheus benchmark: 44 #
# ==== Problem ====
# spread(separate(neg_gather(@param0, ['1']), 2), 3, 4)
# ==== beam search ====
# #1, -4.8384, summarise(group_by(gather(@param0, ['3', '6']), ['4', '6']), max, 5)
# #2, -5.2062, summarise(group_by(gather(@param0, ['1', '2']), ['3', '5']), max, 2)
# #3, -5.2414, summarise(group_by(gather(@param0, ['3', '5']), ['1', '6']), mean, 2)
# #4, -5.3121, summarise(group_by(gather(@param0, ['3', '4']), ['4', '6']), mean, 6)
# #5, -5.4810, summarise(group_by(gather(@param0, ['3', '4']), ['2', '6']), mean, 6)
# #6, -5.5256, summarise(group_by(gather(@param0, ['1', '4']), ['2', '6']), mean, 6)
# #7, -5.5778, summarise(group_by(gather(@param0, ['1', '3']), ['4', '6']), mean, 6)
# #8, -5.8405, summarise(group_by(gather(@param0, ['1', '3']), ['4', '6']), sum, 4)
# #9, -5.8787, summarise(group_by(gather(@param0, ['1', '4']), ['2', '6']), min, 2)
# #10, -5.8937, summarise(group_by(gather(@param0, ['1', '2']), ['2', '6']), mean, 6)
# ==== dead list (11) ====
#
#
# # Start Beam Search...
# # load Morpheus benchmark: 47 #
# ==== Problem ====
# spread(unite(gather(@param0, ['3', '4']), 3, 2), 2, 3)
# ==== beam search ====
# #1, -4.7118, summarise(group_by(neg_gather(@param0, ['3', '4']), ['3', '4']), mean, 2)
# #2, -5.2134, summarise(group_by(neg_gather(@param0, ['3', '4']), ['3', '4']), sum, 2)
# #3, -5.2654, summarise(group_by(neg_gather(@param0, ['3', '4']), ['1', '3']), max, 2)
# #4, -5.2740, summarise(group_by(neg_gather(@param0, ['3', '4']), ['3', '4']), max, 2)
# #5, -5.3446, summarise(group_by(neg_gather(@param0, ['3', '4']), ['1', '3']), mean, 2)
# #6, -5.4896, summarise(group_by(neg_gather(@param0, ['3', '4']), ['3', '4']), min, 2)
# #7, -5.6657, summarise(group_by(neg_gather(@param0, ['3', '4']), ['3']), mean, 2)
# #8, -5.7123, summarise(group_by(neg_gather(@param0, ['3', '4']), ['1', '2']), mean, 2)
# #9, -5.9317, summarise(group_by(neg_gather(@param0, ['3', '4']), ['2', '4']), max, 2)
# #10, -6.0415, summarise(group_by(neg_gather(@param0, ['3', '4']), ['1', '3']), sum, 2)
# ==== dead list (50) ====
#
#
# # Start Beam Search...
# # load Morpheus benchmark: 51 #
# ==== Problem ====
# spread(unite(gather(@param0, ['3', '4']), 2, 3), 2, 3)
# ==== beam search ====
# #1, -6.8497, summarise(group_by(neg_gather(@param0, ['2', '3']), ['3']), mean, 2)
# #2, -7.1616, summarise(group_by(neg_gather(@param0, ['2', '3']), ['1', '4']), mean, 2)
# #3, -7.1673, summarise(group_by(neg_gather(@param0, ['2', '4']), ['3']), mean, 2)
# #4, -7.3386, summarise(group_by(neg_gather(@param0, ['2', '3']), ['2', '4']), max, 2)
# #5, -7.3646, summarise(group_by(neg_gather(@param0, ['2', '3']), ['2', '4']), mean, 2)
# #6, -7.3924, summarise(group_by(neg_gather(@param0, ['2', '3']), ['2', '4']), sum, 2)
# #7, -7.5646, summarise(group_by(neg_gather(@param0, ['2', '3']), ['1', '4']), sum, 2)
# #8, -7.5677, summarise(group_by(neg_gather(@param0, ['2', '3']), ['1']), sum, 2)
# #9, -7.7051, summarise(group_by(neg_gather(@param0, ['2', '4']), ['1', '3']), mean, 2)
# #10, -7.7605, summarise(group_by(neg_gather(@param0, ['2', '4']), ['2', '4']), mean, 2)
# ==== dead list (49) ====
#
#
# # Start Beam Search...
# # load Morpheus benchmark: 52 #
# ==== Problem ====
# spread(separate(neg_gather(@param0, ['1']), 2), 3, 4)
# ==== beam search ====
# #1, -4.2853, summarise(group_by(gather(@param0, ['3', '6']), ['4', '6']), max, 5)
# #2, -5.5242, summarise(group_by(gather(@param0, ['3', '5']), ['1', '6']), mean, 2)
# #3, -5.8896, summarise(group_by(gather(@param0, ['3', '4']), ['3', '5']), max, 2)
# #4, -6.0493, summarise(group_by(gather(@param0, ['3', '4']), ['4', '6']), mean, 6)
# #5, -6.2844, summarise(group_by(gather(@param0, ['3', '6']), ['4', '6']), mean, 2)
# #6, -6.3620, summarise(group_by(gather(@param0, ['2', '3']), ['2', '5']), mean, 5)
# #7, -6.3679, summarise(group_by(gather(@param0, ['3', '4']), ['2', '6']), min, 2)
# #8, -6.4473, summarise(group_by(gather(@param0, ['3', '4']), ['4', '5']), sum, 2)
# #9, -6.4966, summarise(group_by(gather(@param0, ['3', '4']), ['2', '6']), mean, 6)
# #10, -6.5445, summarise(group_by(gather(@param0, ['3', '5']), ['1', '6']), max, 2)
# ==== dead list (26) ====
#
#
# # Start Beam Search...
# # load Morpheus benchmark: 53 #
# ==== Problem ====
# spread(unite(neg_gather(@param0, ['1', '2']), 2, 3), 2, 3)
# ==== beam search ====
# #1, -6.9106, spread(unite(gather(@param0, ['1', '4']), 5, 1), 1, 4)
# #2, -7.6143, spread(unite(gather(@param0, ['5', '6']), 5, 2), 2, 4)
# #3, -7.7113, spread(unite(gather(@param0, ['3', '5']), 5, 2), 2, 4)
# #4, -7.7921, spread(unite(gather(@param0, ['3', '4']), 5, 2), 2, 4)
# #5, -8.5831, spread(unite(gather(@param0, ['3', '6']), 5, 2), 2, 4)
# #6, -8.6976, spread(unite(gather(@param0, ['1', '4']), 5, 1), 1, 2)
# #7, -9.2618, spread(unite(gather(@param0, ['1', '4']), 5, 1), 1, 3)
# #8, -10.0064, spread(unite(gather(@param0, ['3', '5']), 5, 2), 2, 1)
# #9, -10.2263, spread(unite(gather(@param0, ['5', '6']), 5, 2), 2, 1)
# #10, -10.5784, spread(unite(gather(@param0, ['3', '4']), 5, 2), 2, 1)
# ==== dead list (108) ====
#
#
# # Start Beam Search...
# # load Morpheus benchmark: 56 #
# ==== Problem ====
# spread(unite(neg_gather(@param0, ['1', '2']), 1, 3), 1, 3)
# ==== beam search ====
# #1, -9.7873, spread(unite(gather(@param0, ['1', '2']), 4, 5), 4, 2)
# #2, -9.9440, spread(unite(gather(@param0, ['1', '2']), 4, 5), 4, 1)
# #3, -10.1251, spread(unite(gather(@param0, ['3', '4']), 4, 2), 1, 3)
# #4, -10.3232, spread(unite(gather(@param0, ['1', '2']), 5, 4), 4, 2)
# #5, -10.3713, spread(unite(gather(@param0, ['3', '4']), 4, 2), 2, 4)
# #6, -10.4993, spread(unite(gather(@param0, ['1', '2']), 5, 4), 4, 1)
# #7, -10.5659, spread(unite(gather(@param0, ['3', '4']), 4, 2), 1, 4)
# ==== dead list (57) ====
#
#
# # Start Beam Search...
# # load Morpheus benchmark: 59 #
# ==== Problem ====
# spread(separate(neg_gather(@param0, ['1', '2']), 3), 4, 5)
# ==== beam search ====
# #1, -6.0323, summarise(group_by(gather(@param0, ['3', '6']), ['4', '6']), max, 5)
# #2, -7.4498, summarise(group_by(gather(@param0, ['3', '5']), ['5']), sum, 5)
# #3, -7.8172, summarise(group_by(gather(@param0, ['5', '6']), ['4', '6']), max, 5)
# #4, -7.8468, spread(group_by(gather(@param0, ['2', '3']), ['5']), 1, 4)
# #5, -7.8881, summarise(group_by(gather(@param0, ['3', '5']), ['5']), mean, 5)
# #6, -7.9869, summarise(group_by(gather(@param0, ['3', '6']), ['4', '6']), mean, 5)
# #7, -8.0221, summarise(group_by(gather(@param0, ['3', '6']), ['4', '6']), sum, 5)
# #8, -8.0910, spread(group_by(gather(@param0, ['3', '4']), ['4', '6']), 1, 4)
# #9, -8.2297, summarise(group_by(gather(@param0, ['3', '4']), ['4', '6']), mean, 6)
# #10, -8.3625, summarise(group_by(gather(@param0, ['3', '5']), ['5']), max, 5)
# ==== dead list (93) ====
#
#
# # Start Beam Search...
# # load Morpheus benchmark: 60 #
# ==== Problem ====
# spread(separate(neg_gather(@param0, ['1']), 2), 2, 4)
# ==== beam search ====
# #1, -5.9254, summarise(group_by(neg_gather(@param0, ['2', '5']), ['1', '3']), mean, 2)
# #2, -6.1179, summarise(group_by(neg_gather(@param0, ['2', '5']), ['1', '3']), min, 1)
# #3, -6.2827, summarise(group_by(neg_gather(@param0, ['2', '5']), ['2', '4']), mean, 2)
# #4, -6.4689, summarise(group_by(gather(@param0, ['1', '4']), ['1', '3']), min, 2)
# #5, -6.4700, summarise(group_by(gather(@param0, ['1', '2']), ['3', '5']), max, 2)
# #6, -6.7702, summarise(group_by(neg_gather(@param0, ['2', '5']), ['2', '4']), min, 1)
# #7, -6.7853, summarise(group_by(gather(@param0, ['3', '4']), ['4', '5']), max, 3)
# #8, -6.7937, summarise(group_by(gather(@param0, ['3', '4']), ['3', '5']), max, 2)
# #9, -6.9480, summarise(group_by(gather(@param0, ['3', '4']), ['4', '5']), sum, 2)
# #10, -7.1582, summarise(group_by(neg_gather(@param0, ['2', '5']), ['1', '3']), sum, 1)
# ==== dead list (57) ====
#
#
# # Start Beam Search...
# # load Morpheus benchmark: 61 #
# ==== Problem ====
# spread(separate(neg_gather(@param0, ['1']), 2), 2, 4)
# ==== beam search ====
# #1, -3.7982, summarise(group_by(gather(@param0, ['3', '6']), ['4', '6']), max, 5)
# #2, -5.2295, summarise(group_by(gather(@param0, ['1', '3']), ['4', '6']), max, 5)
# #3, -5.2361, summarise(group_by(gather(@param0, ['3', '4']), ['4', '6']), mean, 6)
# #4, -5.2439, summarise(group_by(gather(@param0, ['1', '4']), ['1', '5']), mean, 6)
# #5, -5.3685, summarise(group_by(gather(@param0, ['1', '2']), ['3', '5']), max, 2)
# #6, -5.3702, summarise(group_by(gather(@param0, ['3', '4']), ['4', '6']), max, 5)
# #7, -5.4230, summarise(group_by(gather(@param0, ['5', '6']), ['4', '6']), max, 5)
# #8, -5.4540, summarise(group_by(gather(@param0, ['3', '5']), ['1', '6']), mean, 2)
# #9, -5.4934, summarise(group_by(gather(@param0, ['1', '3']), ['4', '6']), mean, 6)
# #10, -5.5503, summarise(group_by(gather(@param0, ['1', '3']), ['4', '6']), sum, 4)
# ==== dead list (4) ====
#
#
# # Start Beam Search...
# # load Morpheus benchmark: 63 #
# ==== Problem ====
# spread(unite(neg_gather(@param0, ['1', '2']), 2, 3), 2, 3)
# ==== beam search ====
# #1, -7.9115, spread(group_by(gather(@param0, ['3', '5']), ['1', '3']), 1, 4)
# #2, -7.9767, spread(group_by(gather(@param0, ['3', '5']), ['1', '3']), 1, 3)
# #3, -8.0798, summarise(group_by(gather(@param0, ['3', '5']), ['1', '3']), mean, 3)
# #4, -8.1883, summarise(group_by(gather(@param0, ['3', '5']), ['1', '3']), min, 3)
# #5, -8.3410, spread(group_by(gather(@param0, ['3', '5']), ['1', '3']), 4, 2)
# #6, -8.3418, summarise(group_by(gather(@param0, ['1', '2']), ['3', '5']), max, 2)
# #7, -8.4480, spread(unite(gather(@param0, ['3', '4']), 4, 2), 1, 2)
# #8, -8.4488, spread(unite(gather(@param0, ['3', '5']), 4, 1), 2, 1)
# #9, -8.5987, summarise(group_by(gather(@param0, ['3', '5']), ['2', '3']), max, 3)
# #10, -8.6084, spread(unite(gather(@param0, ['3', '4']), 4, 1), 2, 1)
# ==== dead list (66) ====
#
#
# # Start Beam Search...
# # load Morpheus benchmark: 64 #
# ==== Problem ====
# spread(separate(neg_gather(@param0, ['1', '2']), 3), 3, 5)
# ==== beam search ====
# #1, -4.5834, neg_select(gather(separate(@param0, 2), ['2', '3']), ['4'])
# #2, -4.7008, neg_select(gather(separate(@param0, 2), ['2', '3']), ['1', '5'])
# #3, -4.9150, neg_select(gather(separate(@param0, 2), ['2', '3']), ['3', '4'])
# #4, -5.2699, neg_select(gather(separate(@param0, 2), ['2', '3']), ['5', '6'])
# #5, -5.8277, neg_select(gather(separate(@param0, 2), ['5', '6']), ['3', '6'])
# #6, -6.5124, neg_select(gather(separate(@param0, 2), ['1', '4']), ['5'])
# #7, -6.7572, neg_select(gather(separate(@param0, 2), ['1', '5']), ['3', '4'])
# #8, -6.8124, neg_select(gather(separate(@param0, 2), ['2', '3']), ['1', '6'])
# #9, -6.8183, neg_select(gather(separate(@param0, 2), ['2', '3']), ['2', '4'])
# #10, -6.9175, neg_select(gather(separate(@param0, 2), ['2', '3']), ['3'])
# ==== dead list (42) ====
#
#
# # Start Beam Search...
# # load Morpheus benchmark: 90 #
# ==== Problem ====
# spread(unite(gather(@param0, ['3', '4']), 3, 2), 2, 3)
# ==== beam search ====
# #1, -7.7736, spread(unite(gather(@param0, ['3', '4']), 3, 1), 1, 3)
# #2, -8.1688, spread(unite(gather(@param0, ['3', '4']), 1, 3), 1, 3)
# #3, -8.6437, spread(unite(gather(@param0, ['1', '2']), 4, 3), 3, 2)
# #4, -8.9627, spread(unite(gather(@param0, ['3', '4']), 1, 3), 2, 1)
# #5, -9.7391, spread(unite(gather(@param0, ['3', '4']), 3, 1), 2, 1)
# ==== dead list (59) ====

# %%
# SeqBeam(m_config, m_ps, seq_neo, 22)

# %%
# SeqBeam(m_config, m_ps, seq_neo, 23)

# %%
# SeqBeam(m_config, m_ps, seq_neo, 53)

# %%
# SeqBeam(m_config, m_ps, seq_neo, 56)

# %%
# SeqBeam(m_config, m_ps, seq_neo, 63)

# %%
# SeqBeam(m_config, m_ps, seq_neo, 2)

# %%
# SeqBeam(m_config, m_ps, seq_neo, 3)

# %%
# SeqBeam(m_config, m_ps, seq_neo, 10)
