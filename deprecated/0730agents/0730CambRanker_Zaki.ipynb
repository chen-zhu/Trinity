# %% [markdown]
# ## MetaNeo Ranker
# - tell which pair of tables are functionally/logically closer on execution chain
# - Stage: Cambrian
# - Version: Yorgia

# %%
import logging 
logging.basicConfig(level=logging.CRITICAL)

# %%
import os
import itertools
import copy
import random
import pickle
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.autograd import Variable

# from tensorboardX import SummaryWriter

use_cuda = torch.cuda.is_available()
print("use_cuda: {}".format(use_cuda))
# Out:
# use_cuda: True

# %%
import tyrell.spec as S
from tyrell.decider import Example

# Morpheus Version
from MorpheusInterpreter import *
from ProgramSpace import *

# %%
torch.__version__
# Out:
# '1.0.0'

# %%
'''
dataset for training: load random positive/negative examples every time
'''
class RankerDataset(Dataset):
    def __init__(self, p_config=None, p_dataset=None, p_interpreter=None, p_spec=None):
        self.n_sample = None # should manually assign
        self.interpreter = p_interpreter
        self.spec = p_spec
        self.dataset = p_dataset
        self.config = p_config
        
        # record all possible programs
        self.progs = [
            self.dataset[dkey][0][0]
            for dkey in self.dataset.keys()
        ]
        
        self.n_exp = len(self.progs)
        
    def __len__(self):
        return self.n_sample
    
    '''
    return a single triangle sample
    (input, output1, output2, random)
    A->B, A->C, D
    pos: (A,B), (A,C)
    neg: (B,A), (C,A)
    neg: (B,C), (C,B)
    neg: (A,D), (B,D), (C,D)
    neg: (D,A), (D,B), (D,C)
    '''
    def get_triangle(self):
        # sample (A,B)
        while True:
            d_progAB = random.choice(self.progs)
            d_inputA = self.interpreter.random_table()
            try:
                d_evalB = self.interpreter.eval(
                    d_progAB,
                    [d_inputA],
                )
            except Exception:
                continue
            d_exampleAB = Example(
                input=[d_inputA],
                output=d_evalB,
            )
            d_psAB = ProgramSpace(
                self.spec, self.interpreter,
                d_exampleAB.input, d_exampleAB.output,
            )
            d_psAB.init_by_prog(d_progAB)
            d_checkAB = self.interpreter.sanity_check(d_psAB)
            if d_checkAB[0]:
                break
            else:
                continue
        
        # sample (A,C)
        while True:
            d_progAC = random.choice(self.progs)
            if d_progAC==d_progAB:
                continue
            try:
                d_evalC = self.interpreter.eval(
                    d_progAC,
                    [d_inputA],
                )
            except Exception:
                continue
            d_exampleAC = Example(
                input=[d_inputA],
                output=d_evalC,
            )
            d_psAC = ProgramSpace(
                self.spec, self.interpreter,
                d_exampleAC.input, d_exampleAC.output,
            )
            d_psAC.init_by_prog(d_progAC)
            d_checkAC = self.interpreter.sanity_check(d_psAC)
            if d_checkAC[0]:
                break
            else:
                continue
        
        # then randomly generate a table D
        d_randD = self.interpreter.random_table()
        
        # all (map_r, map_c)
        map_inputA = numpy.array([self.interpreter.camb_get_yorgia(d_inputA,modn=self.config["vocab_size"])])
        map_evalB = numpy.array([self.interpreter.camb_get_yorgia(d_evalB,modn=self.config["vocab_size"])])
        map_evalC = numpy.array([self.interpreter.camb_get_yorgia(d_evalC,modn=self.config["vocab_size"])])
        map_randD = numpy.array([self.interpreter.camb_get_yorgia(d_randD,modn=self.config["vocab_size"])])
        
        return (map_inputA, map_evalB, map_evalC, map_randD)
        
    
    '''
    should always use batch_size=1 so as to ensure the ratio of negative examples
    '''
    def __getitem__(self, p_ind):
        return self.get_triangle()

# %%
class Ranker(nn.Module):
    def __init__(self, p_config=None):
        super(Ranker, self).__init__()
        self.config = p_config
        self.value_embedding = nn.Embedding(
            self.config["vocab_size"],
            self.config["embd_dim"],
        )
        self.fc0 = nn.Linear(
            self.config["embd_dim"] * self.config["max_length"] * 2,
            4096,
        )
        self.fc1 = nn.Linear(
            4096,
            2048,
        )
        self.fc2 = nn.Linear(
            2048,
            128
        )
        self.fc3 = nn.Linear(
            128,
            2
        )
        
    def forward(self, pA, pB, pC, pD):
        # pA/pB/pC/pD: (B=1, seq)
        B = pA.shape[0]
        
        # (B, seq, embd_dim)
        vA = self.value_embedding(pA).view(B, self.config["max_length"]*self.config["embd_dim"])
        vB = self.value_embedding(pB).view(B, self.config["max_length"]*self.config["embd_dim"])
        vC = self.value_embedding(pC).view(B, self.config["max_length"]*self.config["embd_dim"])
        vD = self.value_embedding(pD).view(B, self.config["max_length"]*self.config["embd_dim"])
        
        # (B=2, embd_dim * 2)
        vPOS = torch.cat(
            [
                torch.cat([vA,vB],dim=1),
                torch.cat([vA,vC],dim=1),
            ],dim=0
        )
        
        # (B=10, embd_dim * 2)
        vNEG = torch.cat(
            [
                torch.cat([vB,vA],dim=1),
                torch.cat([vB,vC],dim=1),
                torch.cat([vC,vA],dim=1),
                torch.cat([vC,vB],dim=1),
            ],dim=0
        )
        
        # (B=4*3=12, embd_dim * 2)
        vII = torch.cat([vPOS,vNEG],dim=0)
        
        v00 = F.relu(self.fc0(vII))
        v01 = F.relu(self.fc1(v00))
        v02 = F.relu(self.fc2(v01))
        v03 = self.fc3(v02)
        # == Notice: don't do any activation at the last layer ==
        # (B=4*3=12, 2)
        
        return v03

# %%
def RankerTester(p_config, p_model, pld_test, p_lossfn):
    test_loss_list = []
    test_pPOS_list = []
    test_pNEG_list = []
    test_aPOS_list = []
    test_aNEG_list = []
    test_sPOS_list = []
    test_sNEG_list = []
    for batch_idx, (dA, dB, dC, dD) in enumerate(pld_test):
        p_model.eval()
        if use_cuda:
            tdA = Variable(dA).cuda() # (B=1, map_r, map_c)
            tdB = Variable(dB).cuda() # (B=1, map_r, map_c)
            tdC = Variable(dC).cuda() # (B=1, map_r, map_c)
            tdD = Variable(dD).cuda() # (B=1, map_r, map_c)
            td_label = Variable(torch.tensor(
                [1 for _ in range(2)]+\
                [0 for _ in range(4)]
            )).cuda()
        else:
            tdA = Variable(dA) # (B=1, map_r, map_c)
            tdB = Variable(dB) # (B=1, map_r, map_c)
            tdC = Variable(dC) # (B=1, map_r, map_c)
            tdD = Variable(dD) # (B=1, map_r, map_c)
            td_label = Variable(torch.tensor(
                [1 for _ in range(2)]+\
                [0 for _ in range(4)]
            ))
            
        d_output = p_model(tdA, tdB, tdC, tdD) # (B, 2)
        d_loss = p_lossfn(
            F.log_softmax(d_output, dim=1),
            td_label,
        )
        
        test_loss_list.append(d_loss.cpu().data.numpy())
        test_pPOS_list += F.softmax(d_output,dim=1)[:2,1].cpu().data.tolist()
        test_pNEG_list += F.softmax(d_output,dim=1)[2:,0].cpu().data.tolist()
        test_aPOS_list += (torch.argmax(d_output,dim=1)[:2]==td_label[:2]).cpu().data.tolist()
        test_aNEG_list += (torch.argmax(d_output,dim=1)[2:]==td_label[2:]).cpu().data.tolist()
        test_sPOS_list += F.softmax(d_output,dim=1)[:2,1].cpu().data.tolist()
        test_sNEG_list += F.softmax(d_output,dim=1)[2:,1].cpu().data.tolist()
        
    print("# Test avg.loss:{:.2f}, avg.prob.:{:.2f}/{:.2f}, avg.acc.:{:.2f}/{:.2f}, avg.score:{:.2f}/{:.2f}".format(
        sum(test_loss_list)/len(test_loss_list),
        sum(test_pNEG_list)/len(test_pNEG_list),
        sum(test_pPOS_list)/len(test_pPOS_list),
        sum(test_aNEG_list)/len(test_aNEG_list),
        sum(test_aPOS_list)/len(test_aPOS_list),
        sum(test_sNEG_list)/len(test_sNEG_list), # score is the similarity score
        sum(test_sPOS_list)/len(test_sPOS_list),
    ))

# %%
def RankerTrainer(p_config, p_model, pld_train, pld_test, p_optim, p_lossfn):
    RankerTester(p_config, p_model, pld_test, p_lossfn)
    for d_ep in range(p_config["ranker"]["n_ep"]):
        epoch_loss_list = []
        for batch_idx, (dA, dB, dC, dD) in enumerate(pld_train):
            p_model.train()
            
            if use_cuda:
                tdA = Variable(dA).cuda() # (B=1, map_r, map_c)
                tdB = Variable(dB).cuda() # (B=1, map_r, map_c)
                tdC = Variable(dC).cuda() # (B=1, map_r, map_c)
                tdD = Variable(dD).cuda() # (B=1, map_r, map_c)
                td_label = Variable(torch.tensor(
                    [1 for _ in range(2)]+\
                    [0 for _ in range(4)]
                )).cuda()
            else:
                tdA = Variable(dA) # (B=1, map_r, map_c)
                tdB = Variable(dB) # (B=1, map_r, map_c)
                tdC = Variable(dC) # (B=1, map_r, map_c)
                tdD = Variable(dD) # (B=1, map_r, map_c)
                td_label = Variable(torch.tensor(
                    [1 for _ in range(2)]+\
                    [0 for _ in range(4)]
                ))
                
            # (B=12, 2)
            d_output = p_model(tdA, tdB, tdC, tdD)
            p_optim.zero_grad()
            d_loss = p_lossfn(
                F.log_softmax(d_output, dim=1),
                td_label,
            )
            epoch_loss_list.append(d_loss.cpu().data.numpy())
            d_loss.backward()
            p_optim.step()
            
            print("\r# Training EP:{}, B:{}, ep.loss:{:.2f}".format(
                d_ep, batch_idx, sum(epoch_loss_list),
            ),end="")
        
        # end of epoch print a new line
        print()
        RankerTester(p_config, p_model, pld_test, p_lossfn)
        
        # save the model
        if d_ep%10==0:
            torch.save(p_model.state_dict(), "./saved_models/0730Ranker_Zaki_ep{}.pt".format(d_ep))

# %%
m_interpreter = MorpheusInterpreter()
m_spec = S.parse_file('./example/camb3.tyrell')

m_config = {
    "vocab_size": 2048,
    "embd_dim": 16,
    "max_length": m_interpreter.CAMB_NROW + m_interpreter.CAMB_NCOL,
    "ranker":{
        "data_path": "./0716MDsize1.pkl",
        "train_size": 1000, # how many samples in every epoch
        "test_size": 100,
        "n_ep": 1000000,
    },
}



# load the data and dataset
with open(m_config["ranker"]["data_path"],"rb") as f:
    m_data = pickle.load(f)
    
dt_train = RankerDataset(
    p_config=m_config, 
    p_dataset=m_data, 
    p_interpreter=m_interpreter,
    p_spec=m_spec,
)
dt_train.n_sample = m_config["ranker"]["train_size"]
ld_train = DataLoader(dataset=dt_train, batch_size=1, shuffle=True)

dt_test = RankerDataset(
    p_config=m_config, 
    p_dataset=m_data, 
    p_interpreter=m_interpreter,
    p_spec=m_spec,
)
dt_test.n_sample = m_config["ranker"]["test_size"]
ld_test = DataLoader(dataset=dt_test, batch_size=1, shuffle=True)

m_ranker = Ranker(p_config=m_config)
if use_cuda:
    m_ranker = m_ranker.cuda()
optimizer = torch.optim.Adam(list(m_ranker.parameters()))
lossfn = nn.NLLLoss()

# %%
RankerTrainer(m_config, m_ranker, ld_train, ld_test, optimizer, lossfn)
# Out:
# # Test avg.loss:0.70, avg.prob.:0.49/0.51, avg.acc.:0.02/0.96, avg.score:0.51/0.51
# # Training EP:0, B:999, ep.loss:482.52
# # Test avg.loss:0.44, avg.prob.:0.82/0.58, avg.acc.:0.80/0.77, avg.score:0.18/0.58
# # Training EP:1, B:999, ep.loss:422.03
# # Test avg.loss:0.45, avg.prob.:0.74/0.52, avg.acc.:0.84/0.80, avg.score:0.26/0.52
# # Training EP:2, B:999, ep.loss:397.90
# # Test avg.loss:0.45, avg.prob.:0.84/0.62, avg.acc.:0.83/0.71, avg.score:0.16/0.62
# # Training EP:3, B:999, ep.loss:383.81
# # Test avg.loss:0.36, avg.prob.:0.82/0.56, avg.acc.:0.92/0.74, avg.score:0.18/0.56
# # Training EP:4, B:999, ep.loss:372.19
# # Test avg.loss:0.34, avg.prob.:0.85/0.63, avg.acc.:0.86/0.86, avg.score:0.15/0.63
# # Training EP:5, B:999, ep.loss:340.40
# # Test avg.loss:0.40, avg.prob.:0.79/0.70, avg.acc.:0.77/0.91, avg.score:0.21/0.70
# # Training EP:6, B:999, ep.loss:341.82
# # Test avg.loss:0.37, avg.prob.:0.77/0.69, avg.acc.:0.78/0.92, avg.score:0.23/0.69
# # Training EP:7, B:999, ep.loss:344.31
# # Test avg.loss:0.26, avg.prob.:0.85/0.80, avg.acc.:0.86/0.96, avg.score:0.15/0.80
# # Training EP:8, B:999, ep.loss:348.59
# # Test avg.loss:0.30, avg.prob.:0.85/0.70, avg.acc.:0.86/0.92, avg.score:0.15/0.70
# # Training EP:9, B:999, ep.loss:325.91
# # Test avg.loss:0.32, avg.prob.:0.81/0.74, avg.acc.:0.84/0.92, avg.score:0.19/0.74
# # Training EP:10, B:999, ep.loss:332.85
# # Test avg.loss:0.31, avg.prob.:0.84/0.66, avg.acc.:0.86/0.91, avg.score:0.16/0.66
# # Training EP:11, B:999, ep.loss:318.32
# # Test avg.loss:0.30, avg.prob.:0.85/0.73, avg.acc.:0.86/0.91, avg.score:0.15/0.73
# # Training EP:12, B:999, ep.loss:310.65
# # Test avg.loss:0.41, avg.prob.:0.81/0.72, avg.acc.:0.79/0.89, avg.score:0.19/0.72
# # Training EP:13, B:999, ep.loss:313.33
# # Test avg.loss:0.26, avg.prob.:0.88/0.78, avg.acc.:0.88/0.93, avg.score:0.12/0.78
# # Training EP:14, B:999, ep.loss:301.78
# # Test avg.loss:0.30, avg.prob.:0.86/0.83, avg.acc.:0.86/0.92, avg.score:0.14/0.83
# # Training EP:15, B:999, ep.loss:311.04
# # Test avg.loss:0.35, avg.prob.:0.89/0.63, avg.acc.:0.88/0.77, avg.score:0.11/0.63
# # Training EP:16, B:999, ep.loss:312.17
# # Test avg.loss:0.25, avg.prob.:0.88/0.73, avg.acc.:0.87/0.93, avg.score:0.12/0.73
# # Training EP:17, B:999, ep.loss:300.82
# # Test avg.loss:0.34, avg.prob.:0.87/0.64, avg.acc.:0.83/0.88, avg.score:0.13/0.64
# # Training EP:18, B:999, ep.loss:285.35
# # Test avg.loss:0.27, avg.prob.:0.90/0.71, avg.acc.:0.86/0.92, avg.score:0.10/0.71
# # Training EP:19, B:999, ep.loss:290.13
# # Test avg.loss:0.25, avg.prob.:0.87/0.74, avg.acc.:0.86/0.92, avg.score:0.13/0.74
# # Training EP:20, B:999, ep.loss:279.31
# # Test avg.loss:0.25, avg.prob.:0.86/0.75, avg.acc.:0.87/0.93, avg.score:0.14/0.75
# # Training EP:21, B:999, ep.loss:284.50
# # Test avg.loss:0.31, avg.prob.:0.85/0.76, avg.acc.:0.84/0.90, avg.score:0.15/0.76
# # Training EP:22, B:999, ep.loss:277.32
# # Test avg.loss:0.29, avg.prob.:0.84/0.73, avg.acc.:0.84/0.90, avg.score:0.16/0.73
# # Training EP:23, B:999, ep.loss:282.56
# # Test avg.loss:0.31, avg.prob.:0.85/0.75, avg.acc.:0.82/0.89, avg.score:0.15/0.75
# # Training EP:24, B:999, ep.loss:282.59
# # Test avg.loss:0.32, avg.prob.:0.85/0.75, avg.acc.:0.83/0.89, avg.score:0.15/0.75
# # Training EP:25, B:999, ep.loss:285.53
# # Test avg.loss:0.29, avg.prob.:0.88/0.77, avg.acc.:0.92/0.78, avg.score:0.12/0.77
# # Training EP:26, B:999, ep.loss:307.24
# # Test avg.loss:0.23, avg.prob.:0.87/0.76, avg.acc.:0.87/0.94, avg.score:0.13/0.76
# # Training EP:27, B:999, ep.loss:281.57
# # Test avg.loss:0.30, avg.prob.:0.86/0.68, avg.acc.:0.94/0.70, avg.score:0.14/0.68
# # Training EP:28, B:999, ep.loss:279.47
# # Test avg.loss:0.27, avg.prob.:0.86/0.74, avg.acc.:0.85/0.91, avg.score:0.14/0.74
# # Training EP:29, B:999, ep.loss:294.49
# # Test avg.loss:0.27, avg.prob.:0.88/0.70, avg.acc.:0.86/0.92, avg.score:0.12/0.70
# # Training EP:30, B:999, ep.loss:276.76
# # Test avg.loss:0.24, avg.prob.:0.87/0.78, avg.acc.:0.86/0.93, avg.score:0.13/0.78
# # Training EP:31, B:999, ep.loss:270.33
# # Test avg.loss:0.29, avg.prob.:0.85/0.71, avg.acc.:0.84/0.89, avg.score:0.15/0.71
# # Training EP:32, B:999, ep.loss:281.22
# # Test avg.loss:0.33, avg.prob.:0.85/0.69, avg.acc.:0.91/0.70, avg.score:0.15/0.69
# # Training EP:33, B:999, ep.loss:276.77
# # Test avg.loss:0.32, avg.prob.:0.84/0.70, avg.acc.:0.91/0.69, avg.score:0.16/0.70
# # Training EP:34, B:999, ep.loss:267.34
# # Test avg.loss:0.24, avg.prob.:0.93/0.71, avg.acc.:0.97/0.72, avg.score:0.07/0.71
# # Training EP:35, B:999, ep.loss:269.72
# # Test avg.loss:0.24, avg.prob.:0.87/0.85, avg.acc.:0.89/0.90, avg.score:0.13/0.85
# # Training EP:36, B:999, ep.loss:302.48
# # Test avg.loss:0.25, avg.prob.:0.89/0.75, avg.acc.:0.85/0.93, avg.score:0.11/0.75
# # Training EP:37, B:999, ep.loss:273.91
# # Test avg.loss:0.28, avg.prob.:0.88/0.74, avg.acc.:0.92/0.73, avg.score:0.12/0.74
# # Training EP:38, B:999, ep.loss:265.42
# # Test avg.loss:0.29, avg.prob.:0.84/0.81, avg.acc.:0.85/0.92, avg.score:0.16/0.81
# # Training EP:39, B:999, ep.loss:268.52
# # Test avg.loss:0.25, avg.prob.:0.87/0.73, avg.acc.:0.94/0.79, avg.score:0.13/0.73
# # Training EP:40, B:999, ep.loss:264.32
# # Test avg.loss:0.29, avg.prob.:0.83/0.74, avg.acc.:0.91/0.79, avg.score:0.17/0.74
# # Training EP:41, B:999, ep.loss:295.39
# # Test avg.loss:0.24, avg.prob.:0.89/0.74, avg.acc.:0.86/0.92, avg.score:0.11/0.74
# # Training EP:42, B:999, ep.loss:288.66
# # Test avg.loss:0.27, avg.prob.:0.88/0.76, avg.acc.:0.94/0.76, avg.score:0.12/0.76
# # Training EP:43, B:999, ep.loss:255.07
# # Test avg.loss:0.23, avg.prob.:0.90/0.80, avg.acc.:0.88/0.94, avg.score:0.10/0.80
# # Training EP:44, B:999, ep.loss:267.76
# # Test avg.loss:0.28, avg.prob.:0.88/0.71, avg.acc.:0.85/0.90, avg.score:0.12/0.71
# # Training EP:45, B:999, ep.loss:249.90
# # Test avg.loss:0.26, avg.prob.:0.87/0.75, avg.acc.:0.85/0.94, avg.score:0.13/0.75
# # Training EP:46, B:999, ep.loss:276.86
# # Test avg.loss:0.27, avg.prob.:0.86/0.75, avg.acc.:0.92/0.78, avg.score:0.14/0.75
# # Training EP:47, B:999, ep.loss:266.49
# # Test avg.loss:0.21, avg.prob.:0.90/0.81, avg.acc.:0.95/0.81, avg.score:0.10/0.81
# # Training EP:48, B:999, ep.loss:276.16
# # Test avg.loss:0.28, avg.prob.:0.87/0.70, avg.acc.:0.94/0.73, avg.score:0.13/0.70
# # Training EP:49, B:999, ep.loss:260.65
# # Test avg.loss:0.24, avg.prob.:0.88/0.75, avg.acc.:0.87/0.93, avg.score:0.12/0.75
# # Training EP:50, B:999, ep.loss:272.48
# # Test avg.loss:0.26, avg.prob.:0.88/0.73, avg.acc.:0.93/0.72, avg.score:0.12/0.73
# # Training EP:51, B:999, ep.loss:263.93
# # Test avg.loss:0.28, avg.prob.:0.85/0.79, avg.acc.:0.93/0.74, avg.score:0.15/0.79
# # Training EP:52, B:999, ep.loss:275.24
# # Test avg.loss:0.26, avg.prob.:0.86/0.75, avg.acc.:0.94/0.74, avg.score:0.14/0.75
# # Training EP:53, B:999, ep.loss:252.04
# # Test avg.loss:0.24, avg.prob.:0.89/0.77, avg.acc.:0.94/0.74, avg.score:0.11/0.77
# # Training EP:54, B:999, ep.loss:282.30
# # Test avg.loss:0.28, avg.prob.:0.87/0.74, avg.acc.:0.94/0.73, avg.score:0.13/0.74
# # Training EP:55, B:999, ep.loss:280.31
# # Test avg.loss:0.25, avg.prob.:0.87/0.74, avg.acc.:0.93/0.75, avg.score:0.13/0.74
# # Training EP:56, B:999, ep.loss:268.30
# # Test avg.loss:0.26, avg.prob.:0.87/0.73, avg.acc.:0.85/0.90, avg.score:0.13/0.73
# # Training EP:57, B:999, ep.loss:264.65
# # Test avg.loss:0.24, avg.prob.:0.91/0.72, avg.acc.:0.96/0.72, avg.score:0.09/0.72
# # Training EP:58, B:999, ep.loss:249.91
# # Test avg.loss:0.28, avg.prob.:0.87/0.76, avg.acc.:0.90/0.77, avg.score:0.13/0.76
# # Training EP:59, B:999, ep.loss:255.09
# # Test avg.loss:0.28, avg.prob.:0.86/0.78, avg.acc.:0.90/0.83, avg.score:0.14/0.78
# # Training EP:60, B:999, ep.loss:249.42
# # Test avg.loss:0.23, avg.prob.:0.89/0.74, avg.acc.:0.95/0.75, avg.score:0.11/0.74
# # Training EP:61, B:999, ep.loss:260.00
# # Test avg.loss:0.21, avg.prob.:0.90/0.81, avg.acc.:0.94/0.80, avg.score:0.10/0.81
# # Training EP:62, B:999, ep.loss:261.64
# # Test avg.loss:0.26, avg.prob.:0.87/0.71, avg.acc.:0.94/0.70, avg.score:0.13/0.71
# # Training EP:63, B:999, ep.loss:257.98
# # Test avg.loss:0.23, avg.prob.:0.90/0.75, avg.acc.:0.93/0.85, avg.score:0.10/0.75
# # Training EP:64, B:999, ep.loss:247.23
# # Test avg.loss:0.22, avg.prob.:0.88/0.77, avg.acc.:0.95/0.76, avg.score:0.12/0.77
# # Training EP:65, B:514, ep.loss:132.66
