# %% [markdown]
# ## MetaNeo Ranker
# - tell which pair of tables are functionally/logically closer on execution chain
# - Stage: Cambrian
# - Version: Yorgia

# %%
import logging 
logging.basicConfig(level=logging.CRITICAL)

# %%
import os
import itertools
import copy
import random
import pickle
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.autograd import Variable

# from tensorboardX import SummaryWriter

use_cuda = torch.cuda.is_available()
print("use_cuda: {}".format(use_cuda))
# Out:
# use_cuda: True

# %%
import tyrell.spec as S
from tyrell.decider import Example

# Morpheus Version
from MorpheusInterpreter import *
from ProgramSpace import *

# %%
torch.__version__
# Out:
# '1.0.0'

# %%
'''
dataset for training: load random positive/negative examples every time
'''
class RankerDataset(Dataset):
    def __init__(self, p_config=None, p_dataset=None, p_interpreter=None, p_spec=None):
        self.n_sample = None # should manually assign
        self.interpreter = p_interpreter
        self.spec = p_spec
        self.dataset = p_dataset
        self.config = p_config
        
        # record all possible programs
        self.progs = [
            self.dataset[dkey][0][0]
            for dkey in self.dataset.keys()
        ]
        
        self.n_exp = len(self.progs)
        
    def __len__(self):
        return self.n_sample
    
    '''
    return a single triangle sample
    (input, output1, output2, random)
    A->B, A->C, D
    pos: (A,B), (A,C)
    neg: (B,A), (C,A)
    neg: (B,C), (C,B)
    neg: (A,D), (B,D), (C,D)
    neg: (D,A), (D,B), (D,C)
    '''
    def get_triangle(self):
        # sample (A,B)
        while True:
            d_progAB = random.choice(self.progs)
            d_inputA = self.interpreter.random_table()
            try:
                d_evalB = self.interpreter.eval(
                    d_progAB,
                    [d_inputA],
                )
            except Exception:
                continue
            d_exampleAB = Example(
                input=[d_inputA],
                output=d_evalB,
            )
            d_psAB = ProgramSpace(
                self.spec, self.interpreter,
                d_exampleAB.input, d_exampleAB.output,
            )
            d_psAB.init_by_prog(d_progAB)
            d_checkAB = self.interpreter.sanity_check(d_psAB)
            if d_checkAB[0]:
                break
            else:
                continue
        
        # sample (A,C)
        while True:
            d_progAC = random.choice(self.progs)
            if d_progAC==d_progAB:
                continue
            try:
                d_evalC = self.interpreter.eval(
                    d_progAC,
                    [d_inputA],
                )
            except Exception:
                continue
            d_exampleAC = Example(
                input=[d_inputA],
                output=d_evalC,
            )
            d_psAC = ProgramSpace(
                self.spec, self.interpreter,
                d_exampleAC.input, d_exampleAC.output,
            )
            d_psAC.init_by_prog(d_progAC)
            d_checkAC = self.interpreter.sanity_check(d_psAC)
            if d_checkAC[0]:
                break
            else:
                continue
        
        # then randomly generate a table D
        d_randD = self.interpreter.random_table()
        
        # all (map_r, map_c)
        map_inputA = numpy.array([self.interpreter.camb_get_yorgia(d_inputA)])
        map_evalB = numpy.array([self.interpreter.camb_get_yorgia(d_evalB)])
        map_evalC = numpy.array([self.interpreter.camb_get_yorgia(d_evalC)])
        map_randD = numpy.array([self.interpreter.camb_get_yorgia(d_randD)])
        
        return (map_inputA, map_evalB, map_evalC, map_randD)
        
    
    '''
    should always use batch_size=1 so as to ensure the ratio of negative examples
    '''
    def __getitem__(self, p_ind):
        return self.get_triangle()

# %%
class Ranker(nn.Module):
    def __init__(self, p_config=None):
        super(Ranker, self).__init__()
        self.config = p_config
        self.value_embedding = nn.Embedding(
            self.config["vocab_size"],
            self.config["embd_dim"],
        )
        self.fc0 = nn.Linear(
            self.config["embd_dim"] * self.config["max_length"] * 2,
            2048,
        )
        self.fc1 = nn.Linear(
            2048,
            2,
        )
        
    def forward(self, pA, pB, pC, pD):
        # pA/pB/pC/pD: (B=1, seq)
        B = pA.shape[0]
        
        # (B, seq, embd_dim)
        vA = self.value_embedding(pA).view(B, self.config["max_length"]*self.config["embd_dim"])
        vB = self.value_embedding(pB).view(B, self.config["max_length"]*self.config["embd_dim"])
        vC = self.value_embedding(pC).view(B, self.config["max_length"]*self.config["embd_dim"])
        vD = self.value_embedding(pD).view(B, self.config["max_length"]*self.config["embd_dim"])
        
        # (B=2, embd_dim * 2)
        vPOS = torch.cat(
            [
                torch.cat([vA,vB],dim=1),
                torch.cat([vA,vC],dim=1),
            ],dim=0
        )
        
        # (B=10, embd_dim * 2)
        vNEG = torch.cat(
            [
                torch.cat([vB,vA],dim=1),
                torch.cat([vB,vC],dim=1),
                torch.cat([vC,vA],dim=1),
                torch.cat([vC,vB],dim=1),
            ],dim=0
        )
        
        # (B=4*3=12, embd_dim * 2)
        vII = torch.cat([vPOS,vNEG],dim=0)
        
        # == Notice: don't do any activation at the last layer ==
        vOO = self.fc1(
            F.relu(
                self.fc0(
                    vII
                )
            )
        )
        # (B=4*3=12, 2)
        
        return vOO

# %%
def RankerTester(p_config, p_model, pld_test, p_lossfn):
    test_loss_list = []
    test_pPOS_list = []
    test_pNEG_list = []
    test_aPOS_list = []
    test_aNEG_list = []
    test_sPOS_list = []
    test_sNEG_list = []
    for batch_idx, (dA, dB, dC, dD) in enumerate(pld_test):
        p_model.eval()
        if use_cuda:
            tdA = Variable(dA).cuda() # (B=1, map_r, map_c)
            tdB = Variable(dB).cuda() # (B=1, map_r, map_c)
            tdC = Variable(dC).cuda() # (B=1, map_r, map_c)
            tdD = Variable(dD).cuda() # (B=1, map_r, map_c)
            td_label = Variable(torch.tensor(
                [1 for _ in range(2)]+\
                [0 for _ in range(4)]
            )).cuda()
        else:
            tdA = Variable(dA) # (B=1, map_r, map_c)
            tdB = Variable(dB) # (B=1, map_r, map_c)
            tdC = Variable(dC) # (B=1, map_r, map_c)
            tdD = Variable(dD) # (B=1, map_r, map_c)
            td_label = Variable(torch.tensor(
                [1 for _ in range(2)]+\
                [0 for _ in range(4)]
            ))
            
        d_output = p_model(tdA, tdB, tdC, tdD) # (B, 2)
        d_loss = p_lossfn(
            F.log_softmax(d_output, dim=1),
            td_label,
        )
        
        test_loss_list.append(d_loss.cpu().data.numpy())
        test_pPOS_list += F.softmax(d_output,dim=1)[:2,1].cpu().data.tolist()
        test_pNEG_list += F.softmax(d_output,dim=1)[2:,0].cpu().data.tolist()
        test_aPOS_list += (torch.argmax(d_output,dim=1)[:2]==td_label[:2]).cpu().data.tolist()
        test_aNEG_list += (torch.argmax(d_output,dim=1)[2:]==td_label[2:]).cpu().data.tolist()
        test_sPOS_list += F.softmax(d_output,dim=1)[:2,1].cpu().data.tolist()
        test_sNEG_list += F.softmax(d_output,dim=1)[2:,1].cpu().data.tolist()
        
    print("# Test avg.loss:{:.2f}, avg.prob.:{:.2f}/{:.2f}, avg.acc.:{:.2f}/{:.2f}, avg.score:{:.2f}/{:.2f}".format(
        sum(test_loss_list)/len(test_loss_list),
        sum(test_pNEG_list)/len(test_pNEG_list),
        sum(test_pPOS_list)/len(test_pPOS_list),
        sum(test_aNEG_list)/len(test_aNEG_list),
        sum(test_aPOS_list)/len(test_aPOS_list),
        sum(test_sNEG_list)/len(test_sNEG_list), # score is the similarity score
        sum(test_sPOS_list)/len(test_sPOS_list),
    ))

# %%
def RankerTrainer(p_config, p_model, pld_train, pld_test, p_optim, p_lossfn):
    RankerTester(p_config, p_model, pld_test, p_lossfn)
    for d_ep in range(p_config["ranker"]["n_ep"]):
        epoch_loss_list = []
        for batch_idx, (dA, dB, dC, dD) in enumerate(pld_train):
            p_model.train()
            
            if use_cuda:
                tdA = Variable(dA).cuda() # (B=1, map_r, map_c)
                tdB = Variable(dB).cuda() # (B=1, map_r, map_c)
                tdC = Variable(dC).cuda() # (B=1, map_r, map_c)
                tdD = Variable(dD).cuda() # (B=1, map_r, map_c)
                td_label = Variable(torch.tensor(
                    [1 for _ in range(2)]+\
                    [0 for _ in range(4)]
                )).cuda()
            else:
                tdA = Variable(dA) # (B=1, map_r, map_c)
                tdB = Variable(dB) # (B=1, map_r, map_c)
                tdC = Variable(dC) # (B=1, map_r, map_c)
                tdD = Variable(dD) # (B=1, map_r, map_c)
                td_label = Variable(torch.tensor(
                    [1 for _ in range(2)]+\
                    [0 for _ in range(4)]
                ))
                
            # (B=12, 2)
            d_output = p_model(tdA, tdB, tdC, tdD)
            p_optim.zero_grad()
            d_loss = p_lossfn(
                F.log_softmax(d_output, dim=1),
                td_label,
            )
            epoch_loss_list.append(d_loss.cpu().data.numpy())
            d_loss.backward()
            p_optim.step()
            
            print("\r# Training EP:{}, B:{}, ep.loss:{:.2f}".format(
                d_ep, batch_idx, sum(epoch_loss_list),
            ),end="")
        
        # end of epoch print a new line
        print()
        RankerTester(p_config, p_model, pld_test, p_lossfn)
        
        # save the model
        # if d_ep%10==0:
        # torch.save(p_model.state_dict(), "./saved_models/0722CambRanker_Zion_ep{}.pt".format(d_ep))

# %%
m_interpreter = MorpheusInterpreter()
m_spec = S.parse_file('./example/camb3.tyrell')

m_config = {
    "vocab_size": 1024,
    "embd_dim": 16,
    "max_length": m_interpreter.CAMB_NROW + m_interpreter.CAMB_NCOL,
    "ranker":{
        "data_path": "./0716MDsize1.pkl",
        "train_size": 500, # how many samples in every epoch
        "test_size": 100,
        "n_ep": 1000000,
    },
}



# load the data and dataset
with open(m_config["ranker"]["data_path"],"rb") as f:
    m_data = pickle.load(f)
    
dt_train = RankerDataset(
    p_config=m_config, 
    p_dataset=m_data, 
    p_interpreter=m_interpreter,
    p_spec=m_spec,
)
dt_train.n_sample = m_config["ranker"]["train_size"]
ld_train = DataLoader(dataset=dt_train, batch_size=1, shuffle=True)

dt_test = RankerDataset(
    p_config=m_config, 
    p_dataset=m_data, 
    p_interpreter=m_interpreter,
    p_spec=m_spec,
)
dt_test.n_sample = m_config["ranker"]["test_size"]
ld_test = DataLoader(dataset=dt_test, batch_size=1, shuffle=True)

m_ranker = Ranker(p_config=m_config)
if use_cuda:
    m_ranker = m_ranker.cuda()
optimizer = torch.optim.Adam(list(m_ranker.parameters()))
lossfn = nn.NLLLoss()

# %%
RankerTrainer(m_config, m_ranker, ld_train, ld_test, optimizer, lossfn)
# Out:
# # Test avg.loss:0.63, avg.prob.:0.64/0.37, avg.acc.:1.00/0.01, avg.score:0.36/0.37
# # Training EP:0, B:499, ep.loss:248.59
# # Test avg.loss:0.49, avg.prob.:0.71/0.54, avg.acc.:0.83/0.61, avg.score:0.29/0.54
# # Training EP:1, B:499, ep.loss:230.05
# # Test avg.loss:0.40, avg.prob.:0.87/0.47, avg.acc.:0.94/0.43, avg.score:0.13/0.47
# # Training EP:2, B:499, ep.loss:221.42
# # Test avg.loss:0.41, avg.prob.:0.76/0.66, avg.acc.:0.80/0.83, avg.score:0.24/0.66
# # Training EP:3, B:499, ep.loss:207.97
# # Test avg.loss:0.41, avg.prob.:0.73/0.68, avg.acc.:0.75/0.90, avg.score:0.27/0.68
# # Training EP:4, B:499, ep.loss:187.92
# # Test avg.loss:0.41, avg.prob.:0.78/0.58, avg.acc.:0.83/0.76, avg.score:0.22/0.58
# # Training EP:5, B:499, ep.loss:193.18
# # Test avg.loss:0.36, avg.prob.:0.82/0.68, avg.acc.:0.85/0.82, avg.score:0.18/0.68
# # Training EP:6, B:499, ep.loss:192.58
# # Test avg.loss:0.37, avg.prob.:0.83/0.61, avg.acc.:0.84/0.79, avg.score:0.17/0.61
# # Training EP:7, B:499, ep.loss:180.10
# # Test avg.loss:0.36, avg.prob.:0.81/0.75, avg.acc.:0.82/0.89, avg.score:0.19/0.75
# # Training EP:8, B:499, ep.loss:183.75
# # Test avg.loss:0.33, avg.prob.:0.85/0.62, avg.acc.:0.86/0.80, avg.score:0.15/0.62
# # Training EP:9, B:499, ep.loss:167.68
# # Test avg.loss:0.36, avg.prob.:0.83/0.70, avg.acc.:0.83/0.84, avg.score:0.17/0.70
# # Training EP:10, B:499, ep.loss:187.21
# # Test avg.loss:0.36, avg.prob.:0.83/0.64, avg.acc.:0.83/0.88, avg.score:0.17/0.64
# # Training EP:11, B:499, ep.loss:174.02
# # Test avg.loss:0.36, avg.prob.:0.85/0.57, avg.acc.:0.86/0.86, avg.score:0.15/0.57
# # Training EP:12, B:499, ep.loss:173.12
# # Test avg.loss:0.35, avg.prob.:0.83/0.67, avg.acc.:0.83/0.88, avg.score:0.17/0.67
# # Training EP:13, B:499, ep.loss:175.08
# # Test avg.loss:0.34, avg.prob.:0.83/0.65, avg.acc.:0.85/0.91, avg.score:0.17/0.65
# # Training EP:14, B:499, ep.loss:171.92
# # Test avg.loss:0.33, avg.prob.:0.84/0.66, avg.acc.:0.85/0.89, avg.score:0.16/0.66
# # Training EP:15, B:499, ep.loss:169.47
# # Test avg.loss:0.32, avg.prob.:0.85/0.66, avg.acc.:0.85/0.89, avg.score:0.15/0.66
# # Training EP:16, B:499, ep.loss:158.38
# # Test avg.loss:0.31, avg.prob.:0.81/0.73, avg.acc.:0.80/0.94, avg.score:0.19/0.73
# # Training EP:17, B:499, ep.loss:165.26
# # Test avg.loss:0.36, avg.prob.:0.79/0.71, avg.acc.:0.80/0.92, avg.score:0.21/0.71
# # Training EP:18, B:499, ep.loss:171.63
# # Test avg.loss:0.34, avg.prob.:0.83/0.65, avg.acc.:0.83/0.89, avg.score:0.17/0.65
# # Training EP:19, B:499, ep.loss:166.67
# # Test avg.loss:0.36, avg.prob.:0.83/0.67, avg.acc.:0.85/0.85, avg.score:0.17/0.67
# # Training EP:20, B:499, ep.loss:160.01
# # Test avg.loss:0.37, avg.prob.:0.84/0.67, avg.acc.:0.83/0.88, avg.score:0.16/0.67
# # Training EP:21, B:499, ep.loss:167.23
# # Test avg.loss:0.30, avg.prob.:0.87/0.66, avg.acc.:0.84/0.92, avg.score:0.13/0.66
# # Training EP:22, B:499, ep.loss:171.03
# # Test avg.loss:0.32, avg.prob.:0.84/0.69, avg.acc.:0.85/0.88, avg.score:0.16/0.69
# # Training EP:23, B:492, ep.loss:165.64
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-d2e73a8cc945> in <module>
# ----> 1 RankerTrainer(m_config, m_ranker, ld_train, ld_test, optimizer, lossfn)
#
# <ipython-input-8-b651dc14c7ee> in RankerTrainer(p_config, p_model, pld_train, pld_test, p_optim, p_lossfn)
#       3     for d_ep in range(p_config["ranker"]["n_ep"]):
#       4         epoch_loss_list = []
# ----> 5         for batch_idx, (dA, dB, dC, dD) in enumerate(pld_train):
#       6             p_model.train()
#       7
#
# ~/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# --> 615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#     617                 batch = pin_memory_batch(batch)
#
# ~/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py in <listcomp>(.0)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# --> 615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#     617                 batch = pin_memory_batch(batch)
#
# <ipython-input-5-1f0f9f151ba8> in __getitem__(self, p_ind)
#     101     '''
#     102     def __getitem__(self, p_ind):
# --> 103         return self.get_triangle()
#
# <ipython-input-5-1f0f9f151ba8> in get_triangle(self)
#      90         # all (map_r, map_c)
#      91         map_inputA = numpy.array([self.interpreter.camb_get_yorgia(d_inputA)])
# ---> 92         map_evalB = numpy.array([self.interpreter.camb_get_yorgia(d_evalB)])
#      93         map_evalC = numpy.array([self.interpreter.camb_get_yorgia(d_evalC)])
#      94         map_randD = numpy.array([self.interpreter.camb_get_yorgia(d_randD)])
#
# ~/Trinity/MorpheusInterpreter.py in camb_get_yorgia(self, p_obj, verbose)
#     909     '''
#     910     def camb_get_yorgia(self, p_obj, verbose=False):
# --> 911         np_obj, dr, dc = self.camb_get_np_obj(p_obj)
#     912
#     913         table_abs_row_one = [0 for _ in range(self.CAMB_NCOL)]
#
# ~/Trinity/MorpheusInterpreter.py in camb_get_np_obj(self, p_obj)
#     770             # "data frame with 0 columns and 10 rows"
#     771             dr = self.renv('nrow({})'.format(p_obj))[0]
# --> 772             dc = self.renv('ncol({})'.format(p_obj))[0]
#     773             if dr==0 or dc==0:
#     774                 np_obj = numpy.asarray([[]])
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/robjects/__init__.py in __call__(self, string)
#     387     def __call__(self, string):
#     388         p = _rparse(text=StrSexpVector((string,)))
# --> 389         res = self.eval(p)
#     390         return conversion.rpy2py(res)
#     391
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/robjects/__init__.py in __getattribute__(self, attr)
#     362
#     363         try:
# --> 364             return self.__getitem__(attr)
#     365         except LookupError:
#     366             raise AttributeError(orig_ae)
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/robjects/__init__.py in __getitem__(self, item)
#     367
#     368     def __getitem__(self, item):
# --> 369         res = _globalenv.find(item)
#     370         res = conversion.rpy2py(res)
#     371         if hasattr(res, '__rname__'):
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/rinterface_lib/conversion.py in _(*args, **kwargs)
#      26 def _cdata_res_to_rinterface(function):
#      27     def _(*args, **kwargs):
# ---> 28         cdata = function(*args, **kwargs)
#      29         # TODO: test cdata is of the expected CType
#      30         return _cdata_to_rinterface(cdata)
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/rinterface_lib/_rinterface_capi.py in _(*args, **kwargs)
#     229 def _evaluated_promise(function):
#     230     def _(*args, **kwargs):
# --> 231         robj = function(*args, **kwargs)
#     232         if _TYPEOF(robj) == openrlib.rlib.PROMSXP:
#     233             robj = openrlib.rlib.Rf_eval(
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/rinterface.py in find(self, key, wantfun)
#     211                     rho = rho.enclos
#     212             else:
# --> 213                 res = _rinterface._findvar(symbol, self.__sexp__._cdata)
#     214         # TODO: move check of R_UnboundValue to _rinterface ?
#     215         if res == openrlib.rlib.R_UnboundValue:
#
# ~/anaconda3/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/rinterface_lib/memorymanagement.py in rmemory()
#      49         yield pt
#      50     finally:
# ---> 51         pt.unprotect_all()
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/rinterface_lib/memorymanagement.py in unprotect_all(self)
#      39         """Release the total count of objects this instance knows to be
#      40         protected from the protection stack."""
# ---> 41         openrlib.rlib.Rf_unprotect(self._counter)
#      42         self._counter = 0
#      43
#
# KeyboardInterrupt:
