# %% [markdown]
# ## MetaNeo Ranker
# - tell which pair of tables are functionally/logically closer on execution chain
# - Stage: Cambrian
# - Version: Yorgia

# %%
import logging 
logging.basicConfig(level=logging.CRITICAL)

# %%
import os
import itertools
import copy
import random
import pickle
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.autograd import Variable

# from tensorboardX import SummaryWriter

use_cuda = torch.cuda.is_available()
print("use_cuda: {}".format(use_cuda))
# Out:
# use_cuda: True

# %%
import tyrell.spec as S
from tyrell.decider import Example

# Morpheus Version
from MorpheusInterpreter import *
from ProgramSpace import *

# %%
torch.__version__
# Out:
# '1.0.0'

# %%
'''
dataset for training: load random positive/negative examples every time
'''
class RankerDataset(Dataset):
    def __init__(self, p_config=None, p_dataset=None, p_interpreter=None, p_spec=None):
        self.n_sample = None # should manually assign
        self.interpreter = p_interpreter
        self.spec = p_spec
        self.dataset = p_dataset
        self.config = p_config
        
        # record all possible programs
        self.progs = [
            self.dataset[dkey][0][0]
            for dkey in self.dataset.keys()
        ]
        
        self.n_exp = len(self.progs)
        
    def __len__(self):
        return self.n_sample
    
    '''
    return a single triangle sample
    (input, output1, output2, random)
    A->B, A->C, D
    pos: (A,B), (A,C)
    neg: (B,A), (C,A)
    neg: (B,C), (C,B)
    neg: (A,D), (B,D), (C,D)
    neg: (D,A), (D,B), (D,C)
    '''
    def get_triangle(self):
        # sample (A,B)
        while True:
            d_progAB = random.choice(self.progs)
            d_inputA = self.interpreter.random_table()
            try:
                d_evalB = self.interpreter.eval(
                    d_progAB,
                    [d_inputA],
                )
            except Exception:
                continue
            d_exampleAB = Example(
                input=[d_inputA],
                output=d_evalB,
            )
            d_psAB = ProgramSpace(
                self.spec, self.interpreter,
                d_exampleAB.input, d_exampleAB.output,
            )
            d_psAB.init_by_prog(d_progAB)
            d_checkAB = self.interpreter.sanity_check(d_psAB)
            if d_checkAB[0]:
                break
            else:
                continue
        
        # sample (A,C)
        while True:
            d_progAC = random.choice(self.progs)
            if d_progAC==d_progAB:
                continue
            try:
                d_evalC = self.interpreter.eval(
                    d_progAC,
                    [d_inputA],
                )
            except Exception:
                continue
            d_exampleAC = Example(
                input=[d_inputA],
                output=d_evalC,
            )
            d_psAC = ProgramSpace(
                self.spec, self.interpreter,
                d_exampleAC.input, d_exampleAC.output,
            )
            d_psAC.init_by_prog(d_progAC)
            d_checkAC = self.interpreter.sanity_check(d_psAC)
            if d_checkAC[0]:
                break
            else:
                continue
        
        # then randomly generate a table D
        d_randD = self.interpreter.random_table()
        
        # all (map_r, map_c)
        map_inputA = numpy.array([self.interpreter.camb_get_yorgia(d_inputA)])
        map_evalB = numpy.array([self.interpreter.camb_get_yorgia(d_evalB)])
        map_evalC = numpy.array([self.interpreter.camb_get_yorgia(d_evalC)])
        map_randD = numpy.array([self.interpreter.camb_get_yorgia(d_randD)])
        
        return (map_inputA, map_evalB, map_evalC, map_randD)
        
    
    '''
    should always use batch_size=1 so as to ensure the ratio of negative examples
    '''
    def __getitem__(self, p_ind):
        return self.get_triangle()

# %%
class Ranker(nn.Module):
    def __init__(self, p_config=None):
        super(Ranker, self).__init__()
        self.config = p_config
        self.value_embedding = nn.Embedding(
            self.config["vocab_size"],
            self.config["embd_dim"],
            self.config["IDX_PAD"],
        )
        self.fc0 = nn.Linear(
            self.config["embd_dim"] * self.config["max_length"] * 2,
            2048,
        )
        self.fc1 = nn.Linear(
            2048,
            2,
        )
        
    def forward(self, pA, pB, pC, pD):
        # pA/pB/pC/pD: (B=1, seq)
        B = pA.shape[0]
        
        # (B, seq, embd_dim)
        vA = self.value_embedding(pA).view(B, self.config["max_length"]*self.config["embd_dim"])
        vB = self.value_embedding(pB).view(B, self.config["max_length"]*self.config["embd_dim"])
        vC = self.value_embedding(pC).view(B, self.config["max_length"]*self.config["embd_dim"])
        vD = self.value_embedding(pD).view(B, self.config["max_length"]*self.config["embd_dim"])
        
        # (B=2, embd_dim * 2)
        vPOS = torch.cat(
            [
                torch.cat([vA,vB],dim=1),
                torch.cat([vA,vC],dim=1),
            ],dim=0
        )
        
        # (B=10, embd_dim * 2)
        vNEG = torch.cat(
            [
                torch.cat([vB,vA],dim=1),
                torch.cat([vB,vC],dim=1),
                torch.cat([vC,vA],dim=1),
                torch.cat([vC,vB],dim=1),
            ],dim=0
        )
        
        # (B=4*3=12, embd_dim * 2)
        vII = torch.cat([vPOS,vNEG],dim=0)
        
        # == Notice: don't do any activation at the last layer ==
        vOO = self.fc1(
            F.relu(
                self.fc0(
                    vII
                )
            )
        )
        # (B=4*3=12, 2)
        
        return vOO

# %%
def RankerTester(p_config, p_model, pld_test, p_lossfn):
    test_loss_list = []
    test_pPOS_list = []
    test_pNEG_list = []
    test_aPOS_list = []
    test_aNEG_list = []
    test_sPOS_list = []
    test_sNEG_list = []
    for batch_idx, (dA, dB, dC, dD) in enumerate(pld_test):
        p_model.eval()
        if use_cuda:
            tdA = Variable(dA).cuda() # (B=1, map_r, map_c)
            tdB = Variable(dB).cuda() # (B=1, map_r, map_c)
            tdC = Variable(dC).cuda() # (B=1, map_r, map_c)
            tdD = Variable(dD).cuda() # (B=1, map_r, map_c)
            td_label = Variable(torch.tensor(
                [1 for _ in range(2)]+\
                [0 for _ in range(4)]
            )).cuda()
        else:
            tdA = Variable(dA) # (B=1, map_r, map_c)
            tdB = Variable(dB) # (B=1, map_r, map_c)
            tdC = Variable(dC) # (B=1, map_r, map_c)
            tdD = Variable(dD) # (B=1, map_r, map_c)
            td_label = Variable(torch.tensor(
                [1 for _ in range(2)]+\
                [0 for _ in range(4)]
            ))
            
        d_output = p_model(tdA, tdB, tdC, tdD) # (B, 2)
        d_loss = p_lossfn(
            F.log_softmax(d_output, dim=1),
            td_label,
        )
        
        test_loss_list.append(d_loss.cpu().data.numpy())
        test_pPOS_list += F.softmax(d_output,dim=1)[:2,1].cpu().data.tolist()
        test_pNEG_list += F.softmax(d_output,dim=1)[2:,0].cpu().data.tolist()
        test_aPOS_list += (torch.argmax(d_output,dim=1)[:2]==td_label[:2]).cpu().data.tolist()
        test_aNEG_list += (torch.argmax(d_output,dim=1)[2:]==td_label[2:]).cpu().data.tolist()
        test_sPOS_list += F.softmax(d_output,dim=1)[:2,1].cpu().data.tolist()
        test_sNEG_list += F.softmax(d_output,dim=1)[2:,1].cpu().data.tolist()
        
    print("# Test avg.loss:{:.2f}, avg.prob.:{:.2f}/{:.2f}, avg.acc.:{:.2f}/{:.2f}, avg.score:{:.2f}/{:.2f}".format(
        sum(test_loss_list)/len(test_loss_list),
        sum(test_pNEG_list)/len(test_pNEG_list),
        sum(test_pPOS_list)/len(test_pPOS_list),
        sum(test_aNEG_list)/len(test_aNEG_list),
        sum(test_aPOS_list)/len(test_aPOS_list),
        sum(test_sNEG_list)/len(test_sNEG_list), # score is the similarity score
        sum(test_sPOS_list)/len(test_sPOS_list),
    ))

# %%
def RankerTrainer(p_config, p_model, pld_train, pld_test, p_optim, p_lossfn):
    RankerTester(p_config, p_model, pld_test, p_lossfn)
    for d_ep in range(p_config["ranker"]["n_ep"]):
        epoch_loss_list = []
        for batch_idx, (dA, dB, dC, dD) in enumerate(pld_train):
            p_model.train()
            
            if use_cuda:
                tdA = Variable(dA).cuda() # (B=1, map_r, map_c)
                tdB = Variable(dB).cuda() # (B=1, map_r, map_c)
                tdC = Variable(dC).cuda() # (B=1, map_r, map_c)
                tdD = Variable(dD).cuda() # (B=1, map_r, map_c)
                td_label = Variable(torch.tensor(
                    [1 for _ in range(2)]+\
                    [0 for _ in range(4)]
                )).cuda()
            else:
                tdA = Variable(dA) # (B=1, map_r, map_c)
                tdB = Variable(dB) # (B=1, map_r, map_c)
                tdC = Variable(dC) # (B=1, map_r, map_c)
                tdD = Variable(dD) # (B=1, map_r, map_c)
                td_label = Variable(torch.tensor(
                    [1 for _ in range(2)]+\
                    [0 for _ in range(4)]
                ))
                
            # (B=12, 2)
            d_output = p_model(tdA, tdB, tdC, tdD)
            p_optim.zero_grad()
            d_loss = p_lossfn(
                F.log_softmax(d_output, dim=1),
                td_label,
            )
            epoch_loss_list.append(d_loss.cpu().data.numpy())
            d_loss.backward()
            p_optim.step()
            
            print("\r# Training EP:{}, B:{}, ep.loss:{:.2f}".format(
                d_ep, batch_idx, sum(epoch_loss_list),
            ),end="")
        
        # end of epoch print a new line
        print()
        RankerTester(p_config, p_model, pld_test, p_lossfn)
        
        # save the model
        # if d_ep%10==0:
        # torch.save(p_model.state_dict(), "./saved_models/0722CambRanker_Zion_ep{}.pt".format(d_ep))

# %%
m_interpreter = MorpheusInterpreter()
m_spec = S.parse_file('./example/camb3.tyrell')

m_config = {
    "IDX_PAD": 0,
    "vocab_size": 1024,
    "embd_dim": 16,
    "max_length": m_interpreter.CAMB_NROW + m_interpreter.CAMB_NCOL,
    "ranker":{
        "data_path": "./0716MDsize1.pkl",
        "train_size": 500, # how many samples in every epoch
        "test_size": 100,
        "n_ep": 1000000,
    },
}



# load the data and dataset
with open(m_config["ranker"]["data_path"],"rb") as f:
    m_data = pickle.load(f)
    
dt_train = RankerDataset(
    p_config=m_config, 
    p_dataset=m_data, 
    p_interpreter=m_interpreter,
    p_spec=m_spec,
)
dt_train.n_sample = m_config["ranker"]["train_size"]
ld_train = DataLoader(dataset=dt_train, batch_size=1, shuffle=True)

dt_test = RankerDataset(
    p_config=m_config, 
    p_dataset=m_data, 
    p_interpreter=m_interpreter,
    p_spec=m_spec,
)
dt_test.n_sample = m_config["ranker"]["test_size"]
ld_test = DataLoader(dataset=dt_test, batch_size=1, shuffle=True)

m_ranker = Ranker(p_config=m_config)
if use_cuda:
    m_ranker = m_ranker.cuda()
optimizer = torch.optim.Adam(list(m_ranker.parameters()))
lossfn = nn.NLLLoss()

# %%
RankerTrainer(m_config, m_ranker, ld_train, ld_test, optimizer, lossfn)
# Out:
# # Test avg.loss:0.65, avg.prob.:0.58/0.43, avg.acc.:0.96/0.06, avg.score:0.42/0.43
# # Training EP:0, B:499, ep.loss:361.10
# # Test avg.loss:0.67, avg.prob.:0.67/0.38, avg.acc.:0.83/0.29, avg.score:0.33/0.38
# # Training EP:1, B:499, ep.loss:371.03
# # Test avg.loss:0.71, avg.prob.:0.61/0.40, avg.acc.:0.71/0.31, avg.score:0.39/0.40
# # Training EP:2, B:499, ep.loss:371.43
# # Test avg.loss:0.80, avg.prob.:0.72/0.29, avg.acc.:0.82/0.18, avg.score:0.28/0.29
# # Training EP:3, B:499, ep.loss:379.88
# # Test avg.loss:0.82, avg.prob.:0.81/0.22, avg.acc.:0.95/0.08, avg.score:0.19/0.22
# # Training EP:4, B:499, ep.loss:373.21
# # Test avg.loss:0.70, avg.prob.:0.66/0.42, avg.acc.:0.77/0.34, avg.score:0.34/0.42
# # Training EP:5, B:499, ep.loss:362.22
# # Test avg.loss:0.60, avg.prob.:0.67/0.47, avg.acc.:0.82/0.49, avg.score:0.33/0.47
# # Training EP:6, B:499, ep.loss:324.49
# # Test avg.loss:0.64, avg.prob.:0.79/0.35, avg.acc.:0.91/0.28, avg.score:0.21/0.35
# # Training EP:7, B:499, ep.loss:335.76
# # Test avg.loss:0.62, avg.prob.:0.70/0.42, avg.acc.:0.83/0.36, avg.score:0.30/0.42
# # Training EP:8, B:499, ep.loss:311.95
# # Test avg.loss:0.56, avg.prob.:0.74/0.48, avg.acc.:0.84/0.46, avg.score:0.26/0.48
# # Training EP:9, B:499, ep.loss:301.93
# # Test avg.loss:0.59, avg.prob.:0.74/0.48, avg.acc.:0.82/0.49, avg.score:0.26/0.48
# # Training EP:10, B:499, ep.loss:287.98
# # Test avg.loss:0.72, avg.prob.:0.86/0.34, avg.acc.:0.93/0.29, avg.score:0.14/0.34
# # Training EP:11, B:499, ep.loss:299.54
# # Test avg.loss:0.57, avg.prob.:0.80/0.46, avg.acc.:0.88/0.46, avg.score:0.20/0.46
# # Training EP:12, B:499, ep.loss:278.67
# # Test avg.loss:0.52, avg.prob.:0.79/0.51, avg.acc.:0.86/0.51, avg.score:0.21/0.51
# # Training EP:13, B:499, ep.loss:261.43
# # Test avg.loss:0.54, avg.prob.:0.77/0.53, avg.acc.:0.84/0.56, avg.score:0.23/0.53
# # Training EP:14, B:499, ep.loss:271.77
# # Test avg.loss:0.47, avg.prob.:0.76/0.57, avg.acc.:0.82/0.64, avg.score:0.24/0.57
# # Training EP:15, B:499, ep.loss:243.53
# # Test avg.loss:0.49, avg.prob.:0.77/0.54, avg.acc.:0.84/0.54, avg.score:0.23/0.54
# # Training EP:16, B:499, ep.loss:234.57
# # Test avg.loss:0.52, avg.prob.:0.78/0.56, avg.acc.:0.83/0.61, avg.score:0.22/0.56
# # Training EP:17, B:499, ep.loss:241.23
# # Test avg.loss:0.49, avg.prob.:0.83/0.51, avg.acc.:0.90/0.53, avg.score:0.17/0.51
# # Training EP:18, B:499, ep.loss:261.14
# # Test avg.loss:0.40, avg.prob.:0.79/0.65, avg.acc.:0.86/0.73, avg.score:0.21/0.65
# # Training EP:19, B:499, ep.loss:233.77
# # Test avg.loss:0.45, avg.prob.:0.79/0.59, avg.acc.:0.86/0.69, avg.score:0.21/0.59
# # Training EP:20, B:499, ep.loss:230.92
# # Test avg.loss:0.39, avg.prob.:0.80/0.64, avg.acc.:0.85/0.74, avg.score:0.20/0.64
# # Training EP:21, B:499, ep.loss:228.05
# # Test avg.loss:0.50, avg.prob.:0.79/0.58, avg.acc.:0.82/0.69, avg.score:0.21/0.58
# # Training EP:22, B:499, ep.loss:226.41
# # Test avg.loss:0.43, avg.prob.:0.78/0.66, avg.acc.:0.82/0.76, avg.score:0.22/0.66
# # Training EP:23, B:499, ep.loss:234.90
# # Test avg.loss:0.49, avg.prob.:0.79/0.56, avg.acc.:0.85/0.62, avg.score:0.21/0.56
# # Training EP:24, B:499, ep.loss:214.34
# # Test avg.loss:0.38, avg.prob.:0.86/0.57, avg.acc.:0.93/0.65, avg.score:0.14/0.57
# # Training EP:25, B:499, ep.loss:216.24
# # Test avg.loss:0.46, avg.prob.:0.83/0.60, avg.acc.:0.88/0.69, avg.score:0.17/0.60
# # Training EP:26, B:499, ep.loss:217.02
# # Test avg.loss:0.39, avg.prob.:0.78/0.67, avg.acc.:0.83/0.79, avg.score:0.22/0.67
# # Training EP:27, B:499, ep.loss:209.27
# # Test avg.loss:0.45, avg.prob.:0.83/0.58, avg.acc.:0.87/0.67, avg.score:0.17/0.58
# # Training EP:28, B:499, ep.loss:200.50
# # Test avg.loss:0.39, avg.prob.:0.83/0.58, avg.acc.:0.89/0.65, avg.score:0.17/0.58
# # Training EP:29, B:499, ep.loss:215.06
# # Test avg.loss:0.41, avg.prob.:0.79/0.64, avg.acc.:0.86/0.76, avg.score:0.21/0.64
# # Training EP:30, B:29, ep.loss:12.64
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-d2e73a8cc945> in <module>
# ----> 1 RankerTrainer(m_config, m_ranker, ld_train, ld_test, optimizer, lossfn)
#
# <ipython-input-8-b651dc14c7ee> in RankerTrainer(p_config, p_model, pld_train, pld_test, p_optim, p_lossfn)
#       3     for d_ep in range(p_config["ranker"]["n_ep"]):
#       4         epoch_loss_list = []
# ----> 5         for batch_idx, (dA, dB, dC, dD) in enumerate(pld_train):
#       6             p_model.train()
#       7
#
# ~/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# --> 615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#     617                 batch = pin_memory_batch(batch)
#
# ~/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py in <listcomp>(.0)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# --> 615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#     617                 batch = pin_memory_batch(batch)
#
# <ipython-input-5-1f0f9f151ba8> in __getitem__(self, p_ind)
#     101     '''
#     102     def __getitem__(self, p_ind):
# --> 103         return self.get_triangle()
#
# <ipython-input-5-1f0f9f151ba8> in get_triangle(self)
#      52             )
#      53             d_psAB.init_by_prog(d_progAB)
# ---> 54             d_checkAB = self.interpreter.sanity_check(d_psAB)
#      55             if d_checkAB[0]:
#      56                 break
#
# ~/Trinity/MorpheusInterpreter.py in sanity_check(self, p_ps)
#     229             # inputs should not be equal to output
#     230             for i in range(len(p_ps.inputs)):
# --> 231                 if self.equal(p_ps.inputs[i],p_ps.output):
#     232                     return (False, "Rule/IONEQ")
#     233
#
# ~/Trinity/MorpheusInterpreter.py in equal(self, actual, expect)
#      89         # ignoreNames:TRUE, work for benchmark 23
#      90         ret_val = self.renv(_rscript)
# ---> 91         return True == ret_val[0][0]
#      92
#      93     def get_collist(self, sel):
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/robjects/vectors.py in __getitem__(self, i)
#     260
#     261         if isinstance(res, Sexp):
# --> 262             res = conversion.rpy2py(res)
#     263         return res
#     264
#
# ~/anaconda3/lib/python3.7/functools.py in wrapper(*args, **kw)
#     822                             '1 positional argument')
#     823
# --> 824         return dispatch(args[0].__class__)(*args, **kw)
#     825
#     826     funcname = getattr(func, '__name__', 'singledispatch function')
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/robjects/__init__.py in sexpvector_to_ro(obj)
#     119     elif obj.typeof == rinterface.RTYPES.LGLSXP:
#     120         cls = _vector_matrix_array(obj, vectors.BoolVector,
# --> 121                                    vectors.BoolMatrix, vectors.BoolArray)
#     122     elif obj.typeof == rinterface.RTYPES.STRSXP:
#     123         cls = _vector_matrix_array(obj, vectors.StrVector,
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/robjects/__init__.py in _vector_matrix_array(obj, vector_cls, matrix_cls, array_cls)
#      85     # Should it be promoted to array or matrix ?
#      86     try:
# ---> 87         dim = obj.do_slot("dim")
#      88         if len(dim) == 2:
#      89             return matrix_cls
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/rinterface_lib/conversion.py in _(*args, **kwargs)
#      26 def _cdata_res_to_rinterface(function):
#      27     def _(*args, **kwargs):
# ---> 28         cdata = function(*args, **kwargs)
#      29         # TODO: test cdata is of the expected CType
#      30         return _cdata_to_rinterface(cdata)
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/rinterface_lib/sexp.py in do_slot(self, name)
#     144         cchar = conversion._str_to_cchar(name)
#     145         with memorymanagement.rmemory() as rmemory:
# --> 146             name_r = rmemory.protect(openrlib.rlib.Rf_install(cchar))
#     147             if not _rinterface._has_slot(self.__sexp__._cdata, name_r):
#     148                 raise LookupError(name)
#
# KeyboardInterrupt:
