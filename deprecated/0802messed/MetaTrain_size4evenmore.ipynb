# %% [markdown]
# ## TransNeo/AlphaNeo
# - AlphaNeo using pre-trained TransE embeddings (optional)
# - Stage: Cambrian
# - Version: Spriggina
# - Update Logs
#     - 0713: with DeepPath style rollback at training
#     - **0716: new learning paradigm, see memo for details**
#
# #### Related Commands
# - tensorboard --logdir runs
# - nohup jupyter lab > jupyter.log &

# %%
import logging 
logging.basicConfig(level=logging.CRITICAL)

# %%
import os
import itertools
import copy
import random
import pickle
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.autograd import Variable

# from tensorboardX import SummaryWriter

use_cuda = torch.cuda.is_available()
print("use_cuda: {}".format(use_cuda))
# Out:
# use_cuda: True

# %%
import tyrell.spec as S
from tyrell.decider import Example

# Morpheus Version
from MorpheusInterpreter import *
from ProgramSpace import *

# %%
torch.__version__
# Out:
# '1.0.0'

# %%
class TransNeo(nn.Module):
    def __init__(self, p_config=None):
        super(TransNeo, self).__init__()
        self.config = p_config
        
        # predict a fixed number of shells
#         self.policy = nn.Linear(
#             self.config["embd_dim"],
#             self.config["fn"]["vocab_size"],
#         )
        
        # deeper
        self.policy0 = nn.Linear(
            self.config["embd_dim"],
            128,
        )
        self.policy1 = nn.Linear(
            128,
            self.config["fn"]["vocab_size"],
        )
        
    def forward(self, p_mapin, p_mapout):
        # p_mapin/p_mapout: (B, 15*3)
        v_delta = p_mapout-p_mapin
#         tmp_out = torch.log_softmax(
#             self.policy(v_delta),dim=1
#         )
        tmp_out = torch.log_softmax(
            self.policy1(
                F.relu(
                    self.policy0(
                        v_delta
                    )
                )
            ),dim=1
        )
        
        return tmp_out

# %%
# replace certain node id with certain value
def modify_shell(p_shell, p_id_from, p_id_to):
    d_prod = p_shell[0]
    d_rhs = p_shell[1]
    ld_rhs = [p_id_to if d_rhs[i]==p_id_from else d_rhs[i]
             for i in range(len(d_rhs))]
    return (d_prod, tuple(ld_rhs))


'''
meta-train the agent in a supervised way
epoch -> episode, one attempt with hint
NOTICE: only valid for size 1 training
'''
def MetaTrain(p_config, p_spec, p_interpreter, p_generator, p_model, p_optim, p_writer):
    print("# Start Meta-Train...")
    for d_epoch in range(p_config["meta_train"]["n_epoch"]):
        p_model.train()
        
        epoch_loss_list = []
        batch_loss_list = []
        
        for d_ind in range(1000):
            print("\r# epoch:{}, index:{}/{}, avg.loss:{:.2f}".format(
                d_epoch, d_ind, 1000,
                sum(epoch_loss_list)/len(epoch_loss_list)
                if len(epoch_loss_list)>0 else 0,
            ),end="")
            
            # initialize a solution
            ps_solution = p_generator.get_new_chain_program(
                2,
            )
            
            # initialize a new ProgramSpace
            ps_current = ProgramSpace(
                p_spec, p_interpreter, ps_solution.inputs, ps_solution.output,
            )
            # then initialize a shell template
            tmp_shell_list = ps_current.get_neighboring_shells()
            tmp_node_to_replace = ps_current.node_dict["ParamNode"][0] # for chain only
            # replace the Param Node id in shells with -1 to make them templates
            template_list = [
                modify_shell(tmp_shell_list[i],tmp_node_to_replace,-1)
                for i in range(len(tmp_shell_list))
            ]
            
            id_current = ps_current.get_strict_frontiers()[0]
            var_current = ps_current.node_list[id_current].ps_data # need the real var name in r env
            var_output = ps_current.output
            
            map_current = p_interpreter.camb_get_shash_abs(var_current)
            map_output = p_interpreter.camb_get_shash_abs(var_output)
            
            # make current shell list
            current_shell_list = [
                modify_shell(template_list[i],-1,id_current)
                for i in range(len(template_list))
            ]
            
            # wrap in B=1
            if use_cuda:
                td_current = Variable(torch.tensor([map_current],dtype=torch.float)).cuda()
                td_output = Variable(torch.tensor([map_output],dtype=torch.float)).cuda()
            else:
                td_current = Variable(torch.tensor([map_current],dtype=torch.float))
                td_output = Variable(torch.tensor([map_output],dtype=torch.float))

            # (B=1, fn_vocab_size)
            td_pred = p_model(td_current, td_output)
            # directly give the hint / supervised, ps.solution.shell[0] works for 1
            tmp_id = current_shell_list.index(ps_solution.shells[0])
            d_loss = (+1)*(-td_pred[0,tmp_id])
            batch_loss_list.append(
                d_loss, # supervised / always correct with +1 reward
            )
            epoch_loss_list.append(
                d_loss.cpu().data.numpy(),
            )
            
            if len(batch_loss_list)%p_config["meta_train"]["batch_size"]==0:
                # do back-prop.
                if len(batch_loss_list)>0:
                    batch_loss = sum(batch_loss_list)/len(batch_loss_list)
                    p_optim.zero_grad()
                    batch_loss.backward()
                    p_optim.step()
                # after back-prop., clean up
                batch_loss = None
                batch_loss_list = []
                
        print()

# %%
def compare_sketch(ps0,ps1):
    if len(ps0.node_list)!=len(ps1.node_list):
        return False
    for i in range(len(ps0.shells)):
        if ps0.node_list[-i-1].name != ps1.node_list[-i-1].name:
            return False
    return True

'''
meta-test an agent, directly run into testing / online adaptation
'''
def MetaTest(p_config, p_spec, p_interpreter, p_generator, p_model, p_bmrks, p_optim, p_writer):
    print("# Start Meta-Test...")
    
    n_solved = 0 # track the number of solved problem
    n_sketch_solved = 0
    n_attempt_list = [] # track the number of attempts in every episode
    n_sketch_atlist = [] # track the number of attempts when hitting the sketch
    
    for d_episode in range(p_config["meta_test"]["n_episode"]):
        
        # retrieve the given meta-trained model for testing
        test_model = copy.deepcopy(p_model)
        test_model.train()
        test_optim = torch.optim.Adam(list(test_model.parameters()))
        
        # ==== prepare the benchmark ====
        bmrk_prog, bmrk_str_example = p_bmrks[d_episode]
        bmrk_example = Example(
            input=[p_interpreter.load_data_into_var(p) for p in bmrk_str_example.input],
            output=p_interpreter.load_data_into_var(bmrk_str_example.output),
        )
        ps_solution = ProgramSpace(
            p_spec, p_interpreter, bmrk_example.input, bmrk_example.output,
        )
        ps_solution.init_by_prog(bmrk_prog)
        solution_prod_names = [
            ps_solution.prod_list[p[0]].name for p in ps_solution.shells
        ]
        solution_shells = ps_solution.shells
        
        # solution self-check
        if ps_solution.check_eq() is None:
            print("ERROR, SOLUTION NOT CONSISTENT!")
        
        
#         f = open("./outputs/Sarah3/Problem_{}.txt".format(d_episode), "w")
#         f.write("# Problem: {}\n\n".format(str(ps_solution.node_list[-1])))
#         f.write("# Input:\n{}\n".format(p_interpreter.renv(ps_solution.inputs[0])))
#         f.write("# Output:\n{}\n".format(p_interpreter.renv(ps_solution.output)))
#         f.flush()
        
        is_solved = False
        is_sketch_solved = False
        
        for d_attempt in range(p_config["meta_test"]["maxn_attempt"]):
            
            current_prod_names = []
            current_shells = []
            current_outputs = []
            
            selected_neurons = []
            stored_groups = [] # with lists of neurons of the same production name
            
            # in every new attempt, initialize a new Program Space
            ps_current = ProgramSpace(
                p_spec, p_interpreter, ps_solution.inputs, ps_solution.output,
            )
            # then initialize a shell template
            tmp_shell_list = ps_current.get_neighboring_shells()
            tmp_node_to_replace = ps_current.node_dict["ParamNode"][0] # for chain only
            # replace the Param Node id in shells with -1 to make them templates
            template_list = [
                modify_shell(tmp_shell_list[i],tmp_node_to_replace,-1)
                for i in range(len(tmp_shell_list))
            ]
                
            d_step = 0
            while d_step<p_config["meta_test"]["maxn_step"]:
                
                # print the training progress
                print("\r# AC/SK/EP:{}/{}/{}, AT:{}, SP:{}, att.ske.:{:.2f}, att.prog.:{:.2f},".format(
                    n_solved, n_sketch_solved, d_episode, d_attempt, d_step,
                    sum(n_sketch_atlist)/len(n_sketch_atlist) if len(n_sketch_atlist)>0 else -1,
                    sum(n_attempt_list)/len(n_attempt_list) if len(n_attempt_list)>0 else -1,
                ),end="")
                
                # ### assume chain execution, so only 1 possible returns
                # ### at d_step=0, this should be input[0]
                id_current = ps_current.get_strict_frontiers()[0]
                var_current = ps_current.node_list[id_current].ps_data # need the real var name in r env
                var_output = ps_current.output
                
                map_current = p_interpreter.camb_get_shash_abs(var_current)
                map_output = p_interpreter.camb_get_shash_abs(var_output)
                
                # make current shell list
                current_shell_list = [
                    modify_shell(template_list[i],-1,id_current)
                    for i in range(len(template_list))
                ]
                
                # wrap in B=1
                if use_cuda:
                    td_current = Variable(torch.tensor([map_current],dtype=torch.float)).cuda()
                    td_output = Variable(torch.tensor([map_output],dtype=torch.float)).cuda()
                else:
                    td_current = Variable(torch.tensor([map_current],dtype=torch.float))
                    td_output = Variable(torch.tensor([map_output],dtype=torch.float))
                    
                # (B=1, fn_vocab_size)
                td_pred = test_model(td_current, td_output)
                
                # no hints
                if random.random()<=p_config["meta_test"]["exploration_rate"]:
                    # exploration
                    tmp_id = random.choice(range(len(current_shell_list)))
                else:
                    # exploitation
                    # tmp_id = torch.multinomial(td_pred.exp().flatten(), 1).cpu().flatten().numpy()[0]
                    tmp_id = torch.argmax(td_pred.flatten()).cpu().tolist()
                    
                    
                # == Yorgia ==
                # find out all other shells that share the same product name
                tmp_component_name = ps_current.prod_list[current_shell_list[tmp_id][0]].name
                tmp_group = []
                for i in range(len(current_shell_list)):
                    if ps_current.prod_list[current_shell_list[i][0]].name==tmp_component_name:
                        tmp_group.append(td_pred[0,i])
                stored_groups.append(tmp_group)
                    
                # == Yorgia ==
                # add prod names first
                current_prod_names.append(tmp_component_name)
                # then add shells
                current_shells.append(current_shell_list[tmp_id])
                
                # update ps_current
                update_status = ps_current.add_neighboring_shell(
                    current_shell_list[tmp_id]
                )
                
                if update_status:
                    # record selected neuron
                    selected_neurons.append((True, td_pred[0,tmp_id]))
                    current_outputs.append(ps_current.node_list[-1].ps_data)
                    d_step += 1
                    
                    # succeed
                    if ps_current.check_eq() is not None:
                        # and solved!
                        is_solved = True
                        n_solved += 1
                        break
                else:
                    selected_neurons.append((False, td_pred[0,tmp_id]))
                    break
            
            # <END_FOR_STEP>
#             f.write("# ({}) Proposed {}/{}: {}\n".format(
#                 "accept" if is_solved else "reject",
#                 d_attempt, p_config["meta_test"]["maxn_attempt"],
#                 str(ps_current.node_list[-1])
#             ))
#             f.flush()
            
            if not is_sketch_solved:
                if compare_sketch(ps_current, ps_solution):
                    n_sketch_atlist.append(d_attempt)
                    is_sketch_solved = True
                    n_sketch_solved += 1
                    break
                    
            if is_solved:
                n_attempt_list.append(d_attempt)
                break
            
            # print("# Current Sketch: {}".format(current_prod_names))
            # == Yorgia ==
            # compute the loss according to the loss computation rules
            # first component, then function call
            batch_loss_list = []
            for i in range(len(current_prod_names)):
                batch_loss_list.append(
                    (-1.0)*(-selected_neurons[i][1])
                )
#                 if solution_prod_names[i]==current_prod_names[i]:
#                     # component match, promote the whole group
#                     for j in range(len(stored_groups[i])):
#                         batch_loss_list.append(
#                             (+1.0)*(-stored_groups[i][j])
#                         )
#                 else:
#                     for j in range(len(stored_groups[i])):
#                         batch_loss_list.append(
#                             (-1.0)*(-stored_groups[i][j])
#                         )
#                 # then compare function call
#                 if solution_shells[i]==current_shells[i]:
#                     batch_loss_list.append(
#                         (+1.0)*(-selected_neurons[i][1])
#                     )
#                 else:
#                     batch_loss_list.append(
#                         (-1.0)*(-selected_neurons[i][1])
#                     )
            
            batch_loss = sum(batch_loss_list)
            test_optim.zero_grad()
            batch_loss.backward()
            test_optim.step()
            
                
        # <END_FOR_ATTEMPT>     
        
#         f.close()
            
    # <END_FOR_EPISODE>

# %%
m_interpreter = MorpheusInterpreter()
m_spec = S.parse_file('./example/camb3.tyrell')
m_generator = MorpheusGenerator(
    spec=m_spec,
    interpreter=m_interpreter,
)

# dumb variable to help infer the shells
m_ps = ProgramSpace(
    m_spec, m_interpreter, [None], None,
)

m_config = {
    "fn":{
        "vocab_size": len(m_ps.get_neighboring_shells())
    },
    "embd_dim": 15*5,
    # ==== Meta-Learning Setting ==== #
    "meta_train":{
        "n_epoch": 10,
        "batch_size": 8, # how many indices
        "data_path": "./0716MDsize1.pkl",
        "n_truncated": 1000,
    },
    "meta_test":{
        "n_episode": 250, # only pick the first 250
        "batch_size": 1, # how many attempts
        # "fixed_depth": 4,
        "maxn_attempt": 1000,
        "maxn_step": 4, # program size
        "exploration_rate": 0,
        "benchmarks": "./0731MDsize4.pkl",
    },
}

with open(m_config["meta_test"]["benchmarks"],"rb") as f:
    bmrks = pickle.load(f)

trans_neo = TransNeo(p_config=m_config)
if use_cuda:
    trans_neo = trans_neo.cuda()
optimizer = torch.optim.Adam(list(trans_neo.parameters()))

# writer = SummaryWriter("runs/0713CAMB_RL2_camb3")
writer = None

# %%
m_config
# Out:
# {'fn': {'vocab_size': 120},
#  'embd_dim': 75,
#  'meta_train': {'n_epoch': 10,
#   'batch_size': 8,
#   'data_path': './0716MDsize1.pkl',
#   'n_truncated': 1000},
#  'meta_test': {'n_episode': 250,
#   'batch_size': 1,
#   'maxn_attempt': 1000,
#   'maxn_step': 4,
#   'exploration_rate': 0,
#   'benchmarks': './0731MDsize4.pkl'}}

# %%
MetaTrain(m_config, m_spec, m_interpreter, m_generator, trans_neo, optimizer, writer)
# Out:
# # Start Meta-Train...
# # epoch:0, index:999/1000, avg.loss:4.45
# # epoch:1, index:999/1000, avg.loss:3.79
# # epoch:2, index:999/1000, avg.loss:3.44
# # epoch:3, index:999/1000, avg.loss:2.98
# # epoch:4, index:999/1000, avg.loss:2.68
# # epoch:5, index:999/1000, avg.loss:2.51
# # epoch:6, index:999/1000, avg.loss:2.36
# # epoch:7, index:999/1000, avg.loss:2.26
# # epoch:8, index:999/1000, avg.loss:2.13
# # epoch:9, index:999/1000, avg.loss:2.11

# %%
MetaTest(m_config, m_spec, m_interpreter, m_generator, trans_neo, bmrks, optimizer, writer)
# Out:
# # Start Meta-Test...
# # AC/SK/EP:3/26/83, AT:999, SP:0, att.ske.:234.81, att.prog.:246.67,ERROR, SOLUTION NOT CONSISTENT!
# # AC/SK/EP:5/33/114, AT:999, SP:0, att.ske.:221.58, att.prog.:157.60,ERROR, SOLUTION NOT CONSISTENT!
# # AC/SK/EP:5/34/120, AT:999, SP:0, att.ske.:215.91, att.prog.:157.60,ERROR, SOLUTION NOT CONSISTENT!
# # AC/SK/EP:6/35/126, AT:432, SP:2, att.ske.:212.43, att.prog.:136.00,
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-7c3e2755fa43> in <module>
# ----> 1 MetaTest(m_config, m_spec, m_interpreter, m_generator, trans_neo, bmrks, optimizer, writer)
#
# <ipython-input-7-6730025e71cd> in MetaTest(p_config, p_spec, p_interpreter, p_generator, p_model, p_bmrks, p_optim, p_writer)
#     139                 # update ps_current
#     140                 update_status = ps_current.add_neighboring_shell(
# --> 141                     current_shell_list[tmp_id]
#     142                 )
#     143
#
# ~/Trinity/ProgramSpace.py in add_neighboring_shell(self, d_shell, update_node_data)
#     257         if update_node_data:
#     258             try:
# --> 259                 tmp_outv = self.interpreter.eval(self.node_list[d_nid],self.inputs)
#     260                 self.node_list[d_nid].ps_data = tmp_outv
#     261             except InterpreterError as e:
#
# ~/Trinity/tyrell/interpreter/post_order.py in eval(self, prog, inputs)
#      60         node_visitor = NodeVisitor(self)
#      61         try:
# ---> 62             return node_visitor.visit_with_context(prog)
#      63         except InterpreterError as e:
#      64             e.context = node_visitor._context
#
# ~/Trinity/tyrell/interpreter/post_order.py in visit_with_context(self, node)
#      23             def visit_with_context(self, node: Node):
#      24                 self._context.observe(node)
# ---> 25                 res = self.visit(node)
#      26                 self._context.finish(node)
#      27                 return res
#
# ~/Trinity/tyrell/visitor.py in visit(self, node)
#      20         method_name = self._visit_method_name(node)
#      21         visitor = getattr(self, method_name, self.generic_visit)
# ---> 22         return visitor(node)
#      23
#      24     def generic_visit(self, node):
#
# ~/Trinity/tyrell/interpreter/post_order.py in visit_apply_node(self, apply_node)
#      47                 method = getattr(self._interp, method_name,
#      48                                  self._method_not_found)
# ---> 49                 return method(apply_node, in_values)
#      50
#      51             def _method_not_found(self, apply_node: ApplyNode, arg_values: List[Any]):
#
# ~/Trinity/MorpheusInterpreter.py in eval_gather(self, node, args)
#     567         ret_df_name = self.get_fresh_name()
#     568         _script = '{ret_df} <- gather({table}, "{KEY}", "{VALUE}", {cols})'.format(
# --> 569                    ret_df=ret_df_name, table=args[0], KEY=self.get_fresh_col(args[0],0), VALUE=self.get_fresh_col(args[0],1), cols=self.get_collist(args[1]))
#     570         shadow_maxcnt = self.renv('max({table}[,c({cols})])'.format(
#     571                                     table=self.get_shadow_name(args[0]),
#
# ~/Trinity/MorpheusInterpreter.py in get_fresh_col(self, p_obj, p_ord)
#     118         # F---
#     119         # dstr = self.renv(p_obj).r_repr()
# --> 120         dstr = str(self.renv(p_obj))
#     121         dhsh = (self.hash(dstr)*(p_ord+1))%len(self.words)
#     122         fresh_str = self.words[dhsh]
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/robjects/__init__.py in __call__(self, string)
#     387     def __call__(self, string):
#     388         p = _rparse(text=StrSexpVector((string,)))
# --> 389         res = self.eval(p)
#     390         return conversion.rpy2py(res)
#     391
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/robjects/__init__.py in __getattribute__(self, attr)
#     362
#     363         try:
# --> 364             return self.__getitem__(attr)
#     365         except LookupError:
#     366             raise AttributeError(orig_ae)
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/robjects/__init__.py in __getitem__(self, item)
#     368     def __getitem__(self, item):
#     369         res = _globalenv.find(item)
# --> 370         res = conversion.rpy2py(res)
#     371         if hasattr(res, '__rname__'):
#     372             res.__rname__ = item
#
# ~/anaconda3/lib/python3.7/functools.py in wrapper(*args, **kw)
#     822                             '1 positional argument')
#     823
# --> 824         return dispatch(args[0].__class__)(*args, **kw)
#     825
#     826     funcname = getattr(func, '__name__', 'singledispatch function')
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/robjects/__init__.py in _rpy2py_sexpclosure(obj)
#     205 @default_converter.rpy2py.register(SexpClosure)
#     206 def _rpy2py_sexpclosure(obj):
# --> 207     return SignatureTranslatedFunction(obj)
#     208
#     209
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/robjects/functions.py in __init__(self, sexp, init_prm_translate, on_conflict, symbol_r2python, symbol_check_after)
#     156             prm_translate = init_prm_translate
#     157
# --> 158         formals = self.formals()
#     159         if formals.__sexp__._cdata != rinterface.NULL.__sexp__._cdata:
#     160             (symbol_mapping,
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/robjects/functions.py in formals(self)
#     127         (as the R function 'formals()' would).
#     128         """
# --> 129         res = _formals_fixed(self)
#     130         res = conversion.rpy2py(res)
#     131         return res
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/robjects/functions.py in _formals_fixed(func)
#      28         return rinterface.NULL
#      29     else:
# ---> 30         return __formals(tmp)
#      31
#      32
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/rinterface_lib/conversion.py in _(*args, **kwargs)
#      26 def _cdata_res_to_rinterface(function):
#      27     def _(*args, **kwargs):
# ---> 28         cdata = function(*args, **kwargs)
#      29         # TODO: test cdata is of the expected CType
#      30         return _cdata_to_rinterface(cdata)
#
# ~/anaconda3/lib/python3.7/site-packages/rpy2/rinterface.py in __call__(self, *args, **kwargs)
#     769                     call_r,
#     770                     embedded.globalenv.__sexp__._cdata,
# --> 771                     error_occured))
#     772             if error_occured[0]:
#     773                 raise embedded.RRuntimeError(_rinterface._geterrmessage())
#
# KeyboardInterrupt:

# %%
# 99/151, 128
