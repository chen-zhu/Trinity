# %%
from MorpheusInterpreter import *
from ProgramSpace import *
# Out:
# R[write to console]:
# Attaching package: ‘compare’
#
#
# R[write to console]: The following object is masked from ‘package:base’:
#
#     isTRUE
#
#
# R[write to console]:
# Attaching package: ‘dplyr’
#
#
# R[write to console]: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# R[write to console]: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
m_interpreter = MorpheusInterpreter()
m_spec = S.parse_file('./example/camb5.tyrell')
m_generator = MorpheusGenerator(m_spec, m_interpreter)

# %%
m_solution = m_generator.get_new_chain_program(2)

# %%
m_solution.shells
# Out:
# [(8, (69, 63, 4))]

# %%
m_ps = ProgramSpace(m_spec, m_interpreter, [None], None)

# %%
m_ps.prod_list[0].name
# Out:
# 'empty'

# %%
str(m_ps.node_list[68])
# Out:
# '<'

# %%
m_ps.get_neighboring_shells()
# Out:
# [(1, (69, 19)),
#  (1, (69, 20)),
#  (1, (69, 21)),
#  (1, (69, 22)),
#  (1, (69, 23)),
#  (1, (69, 24)),
#  (1, (69, 25)),
#  (1, (69, 26)),
#  (1, (69, 27)),
#  (1, (69, 28)),
#  (1, (69, 29)),
#  (1, (69, 30)),
#  (1, (69, 31)),
#  (1, (69, 32)),
#  (1, (69, 33)),
#  (1, (69, 34)),
#  (1, (69, 35)),
#  (1, (69, 36)),
#  (1, (69, 37)),
#  (1, (69, 38)),
#  (1, (69, 39)),
#  (2, (69, 19)),
#  (2, (69, 20)),
#  (2, (69, 21)),
#  (2, (69, 22)),
#  (2, (69, 23)),
#  (2, (69, 24)),
#  (2, (69, 25)),
#  (2, (69, 26)),
#  (2, (69, 27)),
#  (2, (69, 28)),
#  (2, (69, 29)),
#  (2, (69, 30)),
#  (2, (69, 31)),
#  (2, (69, 32)),
#  (2, (69, 33)),
#  (2, (69, 34)),
#  (2, (69, 35)),
#  (2, (69, 36)),
#  (2, (69, 37)),
#  (2, (69, 38)),
#  (2, (69, 39)),
#  (3, (69, 0, 0)),
#  (3, (69, 0, 1)),
#  (3, (69, 0, 2)),
#  (3, (69, 0, 3)),
#  (3, (69, 0, 4)),
#  (3, (69, 0, 5)),
#  (3, (69, 1, 0)),
#  (3, (69, 1, 1)),
#  (3, (69, 1, 2)),
#  (3, (69, 1, 3)),
#  (3, (69, 1, 4)),
#  (3, (69, 1, 5)),
# ...
