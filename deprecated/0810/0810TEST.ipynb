# %%
from MorpheusInterpreter import *
from ProgramSpace import *
# Out:
# R[write to console]:
# Attaching package: ‘compare’
#
#
# R[write to console]: The following object is masked from ‘package:base’:
#
#     isTRUE
#
#
# R[write to console]:
# Attaching package: ‘dplyr’
#
#
# R[write to console]: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# R[write to console]: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
m_interpreter = MorpheusInterpreter()
# m_spec = S.parse_file('./example/set_neg_select.tyrell')
m_spec = S.parse_file('./example/camb6.tyrell')
m_generator = MorpheusGenerator(m_spec, m_interpreter)

# %%
while True:
    m_solution = m_generator.get_new_chain_program(4)
    print(str(m_solution.node_list[-1]))
# Out:
# neg_select(neg_gather(gather(@param0, ['1', '6']), ['1', '5']), ['3'])
# unite(neg_gather(gather(@param0, ['2', '4']), ['2', '3']), 2, 3)
# summarise(group_by(separate(@param0, 3), ['3', '4']), min, 2)
# summarise(group_by(mutate(@param0, /, 2, 4), ['3', '6']), max, 6)
# neg_gather(summarise(group_by(@param0, ['1', '3']), mean, 3), ['3'])
# summarise(mutate(neg_gather(@param0, ['2', '5']), /, 4, 1), min, 4)
# summarise(group_by(mutate(@param0, /, 4, 3), ['1', '2']), max, 4)
# summarise(group_by(mutate(@param0, /, 6, 2), ['2', '4']), min, 2)
# gather(spread(gather(@param0, ['2', '3']), 5, 6), ['1', '6'])
# neg_select(summarise(group_by(@param0, ['3', '5']), max, 5), ['2'])
# select(neg_gather(gather(@param0, ['2', '3']), ['1', '2']), ['2', '3'])
# neg_select(mutate(gather(@param0, ['1', '5']), /, 6, 4), ['2', '4'])
# neg_select(unite(gather(@param0, ['2', '4']), 5, 1), ['5'])
# neg_select(summarise(group_by(@param0, ['1', '3']), sum, 2), ['2', '3'])
# ...

# %%
m_solution = m_generator.get_new_chain_program(4)

# %%
str(m_solution.node_list[-1])

# %%
m_solution.interpreter.print_obj(m_solution.inputs[0])

# %%
m_solution.interpreter.print_obj(m_solution.node_list[-2].ps_data)

# %%
m_solution.interpreter.shadow_dict[m_solution.node_list[-2].ps_data]

# %%
m_solution.interpreter.print_obj(m_solution.output)

# %%
m_solution.interpreter.shadow_dict[m_solution.inputs[0]]

# %%
m_solution.interpreter.shadow_dict[m_solution.output]

# %%
m_solution = m_generator.get_new_size1_program()
print("==== program ====")
print(str(m_solution.node_list[-1]))
print("==== input ====")
m_solution.interpreter.print_obj(m_solution.inputs[0])
print("==== output ====")
m_solution.interpreter.print_obj(m_solution.output)
# Out:
# DBG-PROG: mutate(@param0, /, 4, 4)
# DBG-ERR: <class 'tyrell.interpreter.error.AssertionViolation'>, ()
# DBG-PROG: mutate(@param0, /, 4, 4)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('mutate: Precondition #1 failed.',)
# DBG-PROG: mutate(@param0, /, 4, 4)
# DBG-ERR: <class 'tyrell.interpreter.error.AssertionViolation'>, ()
# DBG-PROG: mutate(@param0, /, 4, 4)
# DBG-ERR: <class 'tyrell.interpreter.error.AssertionViolation'>, ()
# DBG-PROG: mutate(@param0, /, 4, 4)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('mutate: Precondition #1 failed.',)
# DBG-PROG: mutate(@param0, /, 4, 4)
# DBG-ERR: <class 'tyrell.interpreter.error.AssertionViolation'>, ()
# DBG-PROG: mutate(@param0, /, 4, 4)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('mutate: Precondition #1 failed.',)
# DBG-PROG: mutate(@param0, /, 4, 4)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('mutate: Precondition #1 failed.',)
# DBG-PROG: mutate(@param0, /, 4, 4)
# ...
