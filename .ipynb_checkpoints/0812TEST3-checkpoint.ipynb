# %%
# Morpheus Version
from MorpheusInterpreter import *
from ProgramSpace import *
# Out:
# R[write to console]:
# Attaching package: ‘compare’
#
#
# R[write to console]: The following object is masked from ‘package:base’:
#
#     isTRUE
#
#
# R[write to console]:
# Attaching package: ‘dplyr’
#
#
# R[write to console]: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# R[write to console]: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
m_interpreter = MorpheusInterpreter()
m_spec = S.parse_file('./example/camb6.tyrell')
m_generator = MorpheusGenerator(
    spec=m_spec,
    interpreter=m_interpreter,
)
# dumb variable to help infer the shells
p_sourceps = ProgramSpace(
    m_spec, m_interpreter, [None], None,
)

# %%
sam = m_interpreter.random_table(target_sketch=("neg_gather","unite","spread"))
m_interpreter.print_obj(sam)
# Out:
#   masculinist performability overriot undiocesed
# 1   daedalous        steeler       72       mixy
# 2       clops      antecedes      -17   horridly
# 3   redaction        tirling      -78   horridly
# 4   daedalous            dry      -17       mixy
# 5       clops  overrapturize       72   horridly

# %%
p_prog = m_generator.get_new_chain_program(fixed_depth=4, fixed_sketch=("neg_gather","unite","spread"))
# Out:
#                  prevaricatory azide undigest       pitying bacterioagglutinin
# 1           gastrophilist_lets   -28    92.72       midmain       bathochromic
# 2          heartache_holsteins   -28    54.93        acetin           barrooms
# 3     taurobolium_circumvoisin   -28   -85.23    kidnappers           barrooms
# 4      thomisid_paradiplomatic   -28   -29.39     cavalieri           barrooms
# 5           buchanite_lunarian   -28    37.68      pithless           empyesis
# 6         auditive_spheroidism   -28   -76.21       escalin       bathochromic
# 7 unprejudicially_psychopompos   -54    58.84    repaginate       bathochromic
# 8       unguiltless_palaverous   -54   -89.60 overforwardly           empyesis
# 9      pneumonectasia_pandanus   -28   -38.12  ectypography           empyesis
#      egohood dodecadrachm
# 1  chloremia      sardoin
# 2 solitaires      byrnies
# 3 solitaires    brookside
# 4  chloremia    brookside
# 5 solitaires  combustibly
# 6 solitaires      byrnies
# 7 solitaires      byrnies
# 8 solitaires  combustibly
# 9  chloremia      sardoin
#
# DBG-PROG: spread(unite(neg_gather(@param0, ['3']), 6, 2), 5, 1)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['3', '5']), 2, 2), 4, 6)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['6']), 1, 6), 2, 4)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['5', '6']), 6, 3), 5, 4)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['2', '6']), 3, 1), 6, 1)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['2', '5']), 4, 4), 2, 5)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['3', '5']), 1, 1), 4, 4)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['5']), 5, 4), 2, 3)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['5']), 6, 6), 4, 5)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['2', '4']), 3, 2), 3, 5)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['2']), 1, 5), 6, 1)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['5']), 6, 4), 2, 6)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['4']), 5, 3), 5, 1)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['3']), 4, 2), 3, 4)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['1', '2']), 1, 5), 6, 6)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['2', '6']), 4, 4), 6, 2)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['2', '4']), 3, 4), 5, 6)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['1', '6']), 6, 1), 4, 2)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['6']), 6, 4), 3, 3)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['5']), 4, 4), 2, 6)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['3', '6']), 1, 1), 5, 6)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['5']), 2, 6), 5, 5)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['4', '6']), 6, 3), 3, 5)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['2', '4']), 6, 5), 5, 2)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['6']), 3, 1), 2, 6)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['3', '5']), 4, 5), 5, 4)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['1', '6']), 5, 6), 4, 6)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['1', '3']), 3, 3), 4, 2)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['1', '5']), 1, 1), 4, 3)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['3', '6']), 4, 6), 1, 3)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['1']), 1, 4), 4, 6)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['2', '3']), 6, 2), 3, 1)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('spread: Precondition #0 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['5']), 6, 4), 6, 5)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['5', '6']), 2, 6), 3, 6)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['3', '4']), 1, 4), 2, 6)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['1', '4']), 1, 6), 2, 2)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['1', '3']), 1, 2), 5, 1)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['1', '4']), 6, 1), 1, 4)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['5', '6']), 1, 3), 3, 5)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['1', '4']), 3, 2), 3, 6)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['4', '6']), 5, 3), 4, 4)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['4']), 3, 1), 5, 6)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['4', '5']), 1, 5), 3, 6)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['3', '5']), 5, 4), 1, 2)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['2', '6']), 3, 1), 6, 1)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['2']), 4, 6), 5, 6)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['3', '6']), 4, 1), 5, 3)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['3', '6']), 2, 5), 3, 1)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['
 3, 4)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['5', '6']), 6, 4), 6, 4)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['3']), 5, 3), 5, 1)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['3', '4']), 1, 1), 1, 4)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['4', '6']), 3, 6), 3, 1)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['3']), 5, 4), 5, 5)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['2', '3']), 4, 3), 4, 1)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['1', '6']), 5, 3), 6, 6)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['1']), 5, 5), 1, 1)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['2', '6']), 4, 6), 6, 3)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['4', '5']), 4, 4), 5, 6)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['6']), 6, 2), 3, 3)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['2', '6']), 3, 6), 1, 3)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['3', '5']), 1, 2), 3, 5)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['4', '6']), 4, 1), 5, 3)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['1', '2']), 4, 2), 5, 5)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['3', '5']), 3, 5), 3, 6)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['2', '5']), 3, 4), 5, 1)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['1', '3']), 3, 3), 6, 2)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['2', '4']), 4, 1), 6, 1)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['3']), 4, 6), 6, 2)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['5']), 3, 5), 6, 6)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['6']), 2, 1), 6, 5)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
#             xerus widowership    subdivinely        retain telephoners agog
# 1  circumaxillary          41      lucinidae     fanteague      -55.77   82
# 2      bedarkened          39    multispiral          wraw       58.70  -11
# 3       subcavate          -7         shover     caustical      -37.46  -11
# 4           paced          12   miserabilism      birdseed       43.48  -11
# 5         moldier         -78      slungshot     trachling       33.49   82
# 6        twinborn         -11       pigments orbitofrontal       31.91   82
# 7 chemotaxonomist         -64 procryptically       mottles      -97.40  -69
#       pyloruses
# 1    whartonian
# 2 agreeableness
# 3  vapourescent
# 4        tarpot
# 5       folding
# 6    calculates
# 7     agallochs
#
# DBG-PROG: spread(unite(neg_gather(@param0, ['1']), 5, 6), 3, 3)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['1']), 4, 2), 1, 6)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['1', '2']), 5, 6), 3, 4)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['2', '5']), 3, 1), 6, 5)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['4']), 2, 4), 6, 4)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['1', '6']), 6, 3), 2, 2)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['2']), 4, 6), 4, 1)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['2', '4']), 3, 4), 6, 3)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['5', '6']), 6, 5), 5, 5)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['1']), 3, 6), 4, 5)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['2', '3']), 4, 1), 3, 2)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['2', '4']), 6, 2), 1, 3)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['3', '5']), 4, 4), 2, 6)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['2', '4']), 2, 3), 5, 3)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['4', '6']), 3, 3), 3, 2)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['2', '6']), 3, 1), 2, 3)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['3', '6']), 5, 3), 3, 2)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['2', '3']), 1, 2), 1, 4)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['2', '4']), 6, 3), 1, 3)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['1', '4']), 2, 3), 5, 4)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['1', '3']), 6, 2), 3, 6)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['3']), 5, 3), 5, 2)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['1', '2']), 5, 3), 3, 3)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['4', '5']), 1, 3), 6, 3)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['1']), 2, 6), 2, 4)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# DBG-PROG: spread(unite(neg_gather(@param0, ['2', '3']), 1, 5), 3, 4)
# DBG-ERR: <class 'tyrell.interpreter.error.GeneralError'>, ('neg_gather: Precondition #2 failed.',)
# Traceback (most recent call last):
#   File "/Users/joseph/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-4-c4810efe3907>", line 1, in <module>
#     p_prog = m_generator.get_new_chain_program(fixed_depth=4, fixed_sketch=("neg_gather","unite","spread"))
#   File "/Users/joseph/Desktop/UCSB/19spring/Research_Feng/Trinity/MorpheusInterpreter.py", line 1628, in get_new_chain_program
#     fixed_sketch=fixed_sketch,
#   File "/Users/joseph/Desktop/UCSB/19spring/Research_Feng/Trinity/MorpheusInterpreter.py", line 1579, in generate
#     tmp_prog = tmp_enumerator.next()
#   File "/Users/joseph/Desktop/UCSB/19spring/Research_Feng/Trinity/tyrell/enumerator/random.py", line 153, in next
#     return self._generate(self._builder.output, 0)
#   File "/Users/joseph/Desktop/UCSB/19spring/Research_Feng/Trinity/tyrell/enumerator/random.py", line 150, in _generate
#     force_leaf=(curr_depth >= self._fixed_depth - 1))
#   File "/Users/joseph/Desktop/UCSB/19spring/Research_Feng/Trinity/tyrell/enumerator/random.py", line 144, in _do_generate
#     children = [self._generate(x, curr_depth + 1) for x in prod.rhs]
#   File "/Users/joseph/Desktop/UCSB/19spring/Research_Feng/Trinity/tyrell/enumerator/random.py", line 144, in <listcomp>
#     children = [self._generate(x, curr_depth + 1) for x in prod.rhs]
#   File "/Users/joseph/Desktop/UCSB/19spring/Research_Feng/Trinity/tyrell/enumerator/random.py", line 150, in _generate
#     force_leaf=(curr_depth >= self._fixed_depth - 1))
#   File "/Users/joseph/Desktop/UCSB/19spring/Research_Feng/Trinity/tyrell/enumerator/random.py", line 144, in _do_generate
#     children = [self._generate(x, curr_depth + 1) for x in prod.rhs]
#   File "/Users/joseph/Desktop/UCSB/19spring/Research_Feng/Trinity/tyrell/enumerator/random.py", line 144, in <listcomp>
#     children = [self._generate(x, curr_depth + 1) for x in prod.rhs]
#   File "/Users/joseph/Desktop/UCSB/19spring/Research_Feng/Trinity/tyrell/enumerator/random.py", line 150, in _generate
#     force_leaf=(curr_depth >= self._fixed_depth - 1))
#   File "/Users/joseph/Desktop/UCSB/19spring/Research_Feng/Trinity/tyrell/enumerator/random.py", line 146, in _do_generate
#     return self._builder.make_node(prod, children)
#   File "/Users/joseph/Desktop/UCSB/19spring/Research_Feng/Trinity/tyrell/dsl/builder.py", line 48, in make_node
#     return self._make_node(prod, children)
#   File "/Users/joseph/Desktop/UCSB/19spring/Research_Feng/Trinity/tyrell/dsl/builder.py", line 33, in _make_node
#     return ProductionVisitor(children).visit(prod)
#   File "/Users/joseph/Desktop/UCSB/19spring/Research_Feng/Trinity/tyrell/visitor.py", line 20, in visit
#     method_name = self._visit_method_name(node)
#   File "/Users/joseph/Desktop/UCSB/19spring/Research_Feng/Trinity/tyrell/visitor.py", line 32, in _visit_method_name
#     return 'visit_' + camel_to_snake_case(type(node).__name__)
#   File "/Users/joseph/Desktop/UCSB/19spring/Research_Feng/Trinity/tyrell/visitor.py", line 9, in camel_to_snake_case
#     s1 = first_cap_re.sub(r'\1_\2', name)
#   File "/Users/joseph/anaconda3/lib/python3.6/re.py", line 330, in filter
#     def filter(match, template=template):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/joseph/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1806, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/joseph/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1090, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/joseph/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 311, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/joseph/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 345, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/joseph/anaconda3/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/joseph/anaconda3/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/joseph/anaconda3/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/joseph/anaconda3/lib/python3.6/inspect.py", line 739, in getmodule
#     f = getabsfile(module)
#   File "/Users/joseph/anaconda3/lib/python3.6/inspect.py", line 708, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/Users/joseph/anaconda3/lib/python3.6/inspect.py", line 693, in getsourcefile
#     if os.path.exists(filename):
#   File "/Users/joseph/anaconda3/lib/python3.6/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------

# %%
p_prog.node_list[-1]

# %%
m_generator.get_sketch_from_prog(p_prog.node_list[-1])

# %%
GenSketch
# Out:
# {'gather(mutate(gather(': 3,
#  'gather(mutate(neg_gather(': 1,
#  'gather(separate(unite(': 5,
#  'gather(spread(gather(': 3,
#  'gather(spread(neg_gather(': 5,
#  'gather(summarise(group_by(': 83,
#  'gather(unite(gather(': 10,
#  'gather(unite(neg_gather(': 1,
#  'gather(unite(separate(': 5,
#  'mutate(gather(mutate(': 5,
#  'mutate(neg_gather(mutate(': 8,
#  'mutate(spread(gather(': 5,
#  'mutate(spread(neg_gather(': 3,
#  'mutate(summarise(group_by(': 93,
#  'neg_gather(mutate(gather(': 2,
#  'neg_gather(mutate(neg_gather(': 3,
#  'neg_gather(separate(gather(': 1,
#  'neg_gather(separate(unite(': 2,
#  'neg_gather(spread(gather(': 6,
#  'neg_gather(spread(neg_gather(': 4,
#  'neg_gather(spread(unite(': 2,
#  'neg_gather(summarise(group_by(': 65,
#  'neg_gather(unite(gather(': 8,
#  'neg_gather(unite(neg_gather(': 1,
#  'neg_gather(unite(separate(': 4,
#  'neg_select(gather(mutate(': 34,
#  'neg_select(gather(separate(': 45,
#  'neg_select(gather(unite(': 7,
#  'neg_select(mutate(gather(': 32,
#  'neg_select(mutate(neg_gather(': 7,
#  'neg_select(neg_gather(mutate(': 40,
#  'neg_select(neg_gather(separate(': 21,
#  'neg_select(neg_gather(unite(': 9,
#  'neg_select(separate(gather(': 3,
#  'neg_select(separate(unite(': 8,
#  'neg_select(spread(gather(': 22,
#  'neg_select(spread(neg_gather(': 9,
#  'neg_select(summarise(group_by(': 229,
#  'neg_select(unite(gather(': 37,
#  'neg_select(unite(neg_gather(': 4,
#  'neg_select(unite(separate(': 26,
#  'select(gather(mutate(': 22,
#  'select(gather(separate(': 16,
#  'select(gather(unite(': 8,
#  'select(mutate(gather(': 8,
#  'select(mutate(neg_gather(': 2,
#  'select(neg_gather(mutate(': 44,
#  'select(neg_gather(separate(': 8,
#  'select(neg_gather(unite(': 8,
#  'select(separate(gather(': 2,
#  'select(separate(unite(': 1,
#  'select(spread(gather(': 11,
#  'select(spread(neg_gather(': 6,
#  'select(spread(unite(': 1,
#  'select(summarise(group_by(': 258,
#  'select(unite(gather(': 14,
#  'select(unite(neg_gather(': 6,
#  'select(unite(separate(': 11,
#  'separate(summarise(group_by(': 32,
#  'separate(unite(gather(': 7,
#  'separate(unite(separate(': 1,
#  'spread(gather(mutate(': 2,
#  'spread(neg_gather(mutate(': 5,
#  'spread(neg_gather(unite(': 1,
#  'spread(summarise(group_by(': 4,
#  'spread(unite(gather(': 1,
#  'summarise(group_by(gather(': 265,
#  'summarise(group_by(mutate(': 380,
#  'summarise(group_by(neg_gather(': 53,
#  'summarise(group_by(separate(': 78,
#  'summarise(group_by(summarise(': 17,
#  'summarise(group_by(unite(': 21,
#  'unite(gather(separate(': 9,
#  'unite(gather(unite(': 4,
#  'unite(neg_gather(mutate(': 6,
#  'unite(neg_gather(separate(': 5,
#  'unite(neg_gather(unite(': 2,
#  'unite(separate(unite(': 8,
#  'unite(spread(gather(': 3,
#  'unite(spread(neg_gather(': 1,
#  'unite(spread(unite(': 1,
#  'unite(summarise(group_by(': 4}

# %%
bmrk_size3 = [1,2,3,9,10,13,20,21,22,23,31,42,44,47,51,52,53,56,59,60,61,63,64,90,]
p_builder = D.Builder(p_sourceps.spec)
from benchmarks.pldi17_sol import *
def load_benchmark(p_id, p_sourceps, p_builder):
    d_prog = p_builder._from_sexp(solutions[p_id])
    d_input = p_sourceps.interpreter.init_tbl("./benchmarks/pldi17/p{}_input1.csv".format(p_id))
    p_sourceps.interpreter.create_shadow(d_input)
    d_output = p_sourceps.interpreter.init_tbl("./benchmarks/pldi17/p{}_output1.csv".format(p_id))
    p_sourceps.interpreter.create_shadow(d_output)
    d_ps = ProgramSpace(
        p_sourceps.spec, p_sourceps.interpreter, [d_input], d_output,
    )
    d_ps.init_by_prog(d_prog)
    return d_ps

# %%
BSketch
# Out:
# {'neg_select(gather(separate(': 1,
#  'neg_select(mutate(spread(': 1,
#  'spread(separate(neg_gather(': 9,
#  'spread(unite(gather(': 7,
#  'spread(unite(neg_gather(': 4,
#  'summarise(group_by(gather(': 1,
#  'summarise(group_by(neg_gather(': 1}

# %% [markdown]
# #### filter out benchmarks again according to the benchmark distribution

# %%
with open("./0811Size3_Raw/0811Size3Bmrk.pkl","wb") as f:
    dt = pickle.dump(new_dt,f)
