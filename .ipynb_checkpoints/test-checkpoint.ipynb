# %%
import tyrell.spec as S
from tyrell.interpreter import PostOrderInterpreter, GeneralError
from tyrell.enumerator import SmtEnumerator, RandomEnumerator, ExhaustiveEnumerator
from tyrell.decider import Example, ExampleConstraintDecider
from tyrell.synthesizer import Synthesizer
from tyrell.logger import get_logger
from tyrell import dsl as D
import types
from sexpdata import Symbol

# %%
spec = S.parse_file('./example/mChainOneNB.tyrell')
# enumerator = SmtEnumerator(spec, depth=5, loc=5)
enumerator = ExhaustiveEnumerator(spec, max_depth=2)

# %%
shell_list = []
while True:
    tmp_shell = enumerator.next()
    if tmp_shell is None:
        break
    else:
        shell_list.append(tmp_shell)

# %%
str(shell_list[1])
# Out:
# "select(@param0, ['1'])"

# %%
shell_list[1].data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-8a520f0b9039> in <module>()
# ----> 1 shell_list[1].data
#
# AttributeError: 'ApplyNode' object has no attribute 'data'

# %%
dir(shell_list[1])
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_cache',
#  '_abc_negative_cache',
#  '_abc_negative_cache_version',
#  '_abc_registry',
#  '_args',
#  '_prod',
#  'args',
#  'children',
#  'deep_eq',
#  'deep_hash',
#  'is_apply',
#  'is_enum',
#  'is_leaf',
#  'is_param',
#  'name',
#  'production',
#  'to_sexp',
#  'type']

# %%
shell_list[0].children
# Out:
# []

# %%
shell_list[1].children
# Out:
# (ParamNode(0), AtomNode(['1']))

# %%
len(shell_list)
# Out:
# 397

# %%
shell_list
# Out:
# [ParamNode(0),
#  ApplyNode(select, (ParamNode(0), AtomNode(['1']))),
#  ApplyNode(select, (ParamNode(0), AtomNode(['2']))),
#  ApplyNode(select, (ParamNode(0), AtomNode(['3']))),
#  ApplyNode(select, (ParamNode(0), AtomNode(['4']))),
#  ApplyNode(select, (ParamNode(0), AtomNode(['5']))),
#  ApplyNode(select, (ParamNode(0), AtomNode(['6']))),
#  ApplyNode(select, (ParamNode(0), AtomNode(['1', '2']))),
#  ApplyNode(select, (ParamNode(0), AtomNode(['1', '3']))),
#  ApplyNode(select, (ParamNode(0), AtomNode(['1', '4']))),
#  ApplyNode(select, (ParamNode(0), AtomNode(['1', '5']))),
#  ApplyNode(select, (ParamNode(0), AtomNode(['1', '6']))),
#  ApplyNode(select, (ParamNode(0), AtomNode(['2', '3']))),
#  ApplyNode(select, (ParamNode(0), AtomNode(['2', '4']))),
#  ApplyNode(select, (ParamNode(0), AtomNode(['2', '5']))),
#  ApplyNode(select, (ParamNode(0), AtomNode(['2', '6']))),
#  ApplyNode(select, (ParamNode(0), AtomNode(['3', '4']))),
# ...
